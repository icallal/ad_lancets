# %% [markdown]
# NACC - Education, Imaging Data, AD Risk

# %%
import pandas as pd
nacc_df = pd.read_parquet('../../../randy/rfb/raw_data/NACC/investigator_nacc69.parquet', engine = 'fastparquet')

# %%
import pandas as pd
covariates_df = pd.read_parquet('doubleML_dep_AD_covariates.parquet', engine = 'fastparquet')
covariates_df

# %% [markdown]
# UKB - Education, Imaging Data, AD Risk

# %%
import pandas as pd
covariates_df = pd.read_parquet('doubleML_covariates.parquet', engine = 'fastparquet')
imaging_df = pd.read_parquet('../../../randy/rfb/tidy_data/UKBiobank/dementia/neuroimaging/X.parquet', engine = 'fastparquet')

covariates_df.rename(columns = {'IID': 'eid'}, inplace = True)
imaging_only = imaging_df[['eid'] + [col for col in imaging_df.columns if (col.startswith('25') or col.startswith('27') or col.startswith('26'))]]

# %%
imaging_only

# %%
covariates_df = covariates_df.merge(imaging_only, on='eid', how='inner')

# %%
# overlapping only
covariates_df = covariates_df.merge(imaging_only[['eid'] + overlap_image], on='eid', how='inner')
covariates_df = covariates_df.merge(ct_df[['eid'] + overlap_cog], on='eid', how='inner')

# %%
imaging_only.shape[0]

# %%
from doubleml_utils import run_dml_instrument, run_dml 

results = {}

fold = 0

# Impute education years ONCE
covariates_df.dropna(subset = ['education_years'], inplace=True)

startidx = int(imaging_only.shape[0] / 100 * fold)
endidx = int(imaging_only.shape[0] / 100 * (fold + 1))

print(f"Processing fold {fold}: indices {startidx} to {endidx}")

for i in imaging_only.drop(columns=['eid']).columns.tolist()[:1]:
    # Create boolean mask for non-missing values
    valid_mask = ~covariates_df[i].isna()
    
    # Check sample size before proceeding
    n_valid = valid_mask.sum()
    if n_valid < 100:
        print(f"Skipping {i} due to insufficient data ({n_valid} samples)")
        continue

    # Use boolean indexing - no copying!
    covariates_df = covariates_df[valid_mask]

    outcome = covariates_df.loc[valid_mask, i]
    exposure = covariates_df.loc[valid_mask, 'education_years']
    covariates = covariates_df.loc[valid_mask, ['curr_age', '31-0.0', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4']]
    #instrument = covariates_df.loc[valid_mask, '31-0.0']

    try:
        result = run_dml(covariates=covariates, outcome=outcome, exposure=exposure)
        results[i] = result.summary
        print(f"Completed {i}: {n_valid} samples")
    except Exception as e:
        print(f"Error processing {i}: {str(e)}")
        continue

# %%
import pandas as pd
image_to_AD = pd.read_parquet('double_ml/imaging/imaging_image_to_AD.parquet', engine = 'fastparquet')
image_to_AD.sort_values(by='P>|t|', inplace=True)
image_to_AD = image_to_AD[image_to_AD['P>|t|'] < 0.05]

ed_to_image = pd.read_parquet('double_ml/imaging/imaging_ed_to_image.parquet', engine = 'fastparquet')
ed_to_image.sort_values(by='P>|t|', inplace=True)
ed_to_image = ed_to_image[ed_to_image['P>|t|'] < 0.05]
ed_to_image.sort_values(by='coef', key=abs, ascending=False, inplace=True)

overlap = ed_to_image.merge(image_to_AD, on='test_id', how = 'inner')

# %%
overlap_image = list(overlap['test_id'])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
imaging_df_scaled = pd.DataFrame(
    scaler.fit_transform(imaging_only[overlap_image]),
    columns=overlap_image,
    index=imaging_only.index
)
imaging_df_scaled['eid'] = imaging_only['eid'].values

# %% [markdown]
# Cognitive Data

# %%
covariates_df = pd.read_parquet('doubleML_dep_AD_covariates.parquet', engine = 'fastparquet').rename(columns = {'IID': 'eid'})
#ct_df = pd.read_parquet('cognitive_test_results.parquet', engine = 'fastparquet')

# %%
import pandas as pd
cogtest_ids = [f"{x}-2.0" for x in [4282, 20023, 6348, 6349, 6350, 6351, 6333, 20197, 20018, 20016]]
ct_df = pd.read_csv('../../../uk_biobank/project_52887_669338/ukb669338.csv', usecols=['eid'] + cogtest_ids)

# %%
ct_df.to_parquet('cognitive_test_results_2.parquet', engine = 'fastparquet', index=False)

# %%
ct_df

# %%
covariates_df = covariates_df.merge(ct_df, on='eid', how='inner')

# %%
from doubleml_utils import run_dml
results = {}
covariates_df.dropna(subset=['curr_age', '31-0.0', 'groups', 'education_years'], inplace=True)

for test in ct_df.drop(columns=['eid']).columns:
    # Create boolean mask for non-missing values
    valid_mask = ~covariates_df[test].isna()
    
    # Check sample size before proceeding
    n_valid = valid_mask.sum()
    if n_valid < 100:
        print(f"Skipping {test} due to insufficient data ({n_valid} samples)")
        continue

    # Use boolean indexing - no copying!
    outcome = covariates_df.loc[valid_mask, 'groups']
    exposure = covariates_df.loc[valid_mask, test]
    covariates = covariates_df.loc[valid_mask, ['curr_age', '31-0.0', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4']]

    try:
        result = run_dml(covariates, outcome, exposure)
        results[test] = result.summary
        print(f"Completed {test}: {n_valid} samples")
    except Exception as e:
        print(f"Error processing {test}: {str(e)}")
        continue

# %%
results

# %%
from doubleml_utils import summarize_results
results_df = summarize_results(results)
results_df = results_df[results_df['P>|t|'] < 0.05]

# %%
results_df

# %%
results_df.to_csv('double_ml/ed_to_cogtest2.csv', index=False)

# %%
ed_to_cogtest = pd.read_csv('double_ml/ed_to_cogtest2.csv')
cogtest_to_AD = pd.read_csv('double_ml/cogtest2_to_AD.csv')

overlap = set(ed_to_cogtest['test_id']).intersection(set(cogtest_to_AD['test_id']))
overlap_cog = list(overlap)
overlap_cog

# %%
df = pd.read_csv('../../../uk_biobank/project_52887_669338/ukb669338.csv', usecols=['eid', '20132-0.0'])

# %%
df = pd.read_parquet('imaging_ed_cog_brain_FOR_R.parquet', engine = 'fastparquet')
# X = df.drop(columns=overlap_cog + ['education_years'])
df['education_years'].isna().sum()

# %% [markdown]
# Imaging to Cognitive Level - Explaining Variance with Education?

# %%
import pandas as pd
overlap_cog = ['4282-2.0', '20016-2.0', '20023-2.0', '20197-2.0']

covariates_df = pd.read_parquet('doubleML_covariates.parquet', engine = 'fastparquet', columns=['IID', 'education_years', 'curr_age', '31-0.0', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4', 'groups'])
imaging_df = pd.read_parquet('../../../randy/rfb/tidy_data/UKBiobank/dementia/neuroimaging/X.parquet', engine = 'fastparquet', columns=['eid'] + overlap_image)
ct_df = pd.read_parquet('cognitive_test_results_2.parquet', engine = 'fastparquet', columns=['eid'] + overlap_cog)

covariates_df.rename(columns = {'IID': 'eid'}, inplace = True)
covariates_df = covariates_df.merge(imaging_df, on='eid', how='inner').merge(ct_df, on='eid', how='inner')
covariates_df.dropna(subset=['curr_age', '31-0.0', 'groups', 'education_years'], inplace=True)
covariates_df

# %%
from doubleml_utils import run_dml_instrument, run_dml 
import pandas as pd

overlap_cog = ['4282-2.0', '20016-2.0', '20023-2.0', '20197-2.0']
covariates_df = pd.read_parquet('doubleML_covariates.parquet', engine = 'fastparquet', columns=['IID', 'bmi', 'mdi', 'education_years', 'curr_age', '31-0.0', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4', 'groups'])
covariates_df.rename(columns = {'IID': 'eid'}, inplace = True)
ct_df = pd.read_parquet('cognitive_test_results_2.parquet', engine = 'fastparquet', columns=['eid'] + overlap_cog)

imaging_df = pd.read_parquet('../../../randy/rfb/tidy_data/UKBiobank/dementia/neuroimaging/X.parquet', engine = 'fastparquet')
imaging_only = imaging_df[['eid'] + [col for col in imaging_df.columns if (col.startswith('25') or col.startswith('27') or col.startswith('26'))]]

covariates_df = covariates_df.merge(imaging_only, on='eid', how='inner').merge(ct_df, on='eid', how='inner')

results = {}

fold = 0

# Impute education years ONCE
covariates_df.dropna(subset = ['education_years'], inplace=True)

startidx = int(imaging_only.shape[0] / 100 * fold)
endidx = int(imaging_only.shape[0] / 100 * (fold + 1))

print(f"Processing fold {fold}: indices {startidx} to {endidx}")

for i in imaging_only.drop(columns=['eid']).columns.tolist()[0:2]:
    valid_mask = ~covariates_df[i].isna()
    covariates_df = covariates_df[valid_mask]

    results[i] = {}

    for c in ['4282-2.0', '20016-2.0', '20023-2.0', '20197-2.0']:
    # Create boolean mask for non-missing values
        valid_mask = ~covariates_df[c].isna()
        
        # Check sample size before proceeding
        n_valid = valid_mask.sum()
        if n_valid < 100:
            print(f"Skipping {i} due to insufficient data ({n_valid} samples)")
            continue

        # Use boolean indexing - no copying!
        covariates_df = covariates_df[valid_mask]

        outcome = c
        exposure = i
        covariates = ['curr_age', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4']
        instrument = '31-0.0'

        try:
            result = run_dml_instrument(covariates_df, covariates=covariates, outcome=outcome, exposure=exposure, instrument=instrument)
            results[i][c] = result.summary
            print(f"Completed {i}: {n_valid} samples")
        except Exception as e:
            print(f"Error processing {i}: {str(e)}")
            continue

# %%
imaging_only.drop(columns=['eid']).columns.tolist()[0]
# Out:
# '25000-2.0'

# %%
import pandas as pd
overlap_cog = ['4282-2.0', '20016-2.0', '20023-2.0', '20197-2.0']
covariates_df = pd.read_parquet('doubleML_covariates.parquet', engine = 'fastparquet', columns=['IID', 'bmi', 'mdi', 'education_years', 'curr_age', '31-0.0', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4', 'groups'])
covariates_df.rename(columns = {'IID': 'eid'}, inplace = True)
ct_df = pd.read_parquet('cognitive_test_results_2.parquet', engine = 'fastparquet', columns=['eid'] + overlap_cog)

imaging_df = pd.read_parquet('../../../randy/rfb/tidy_data/UKBiobank/dementia/neuroimaging/X.parquet', engine = 'fastparquet')
imaging_only = imaging_df[['eid'] + [col for col in imaging_df.columns if (col.startswith('25') or col.startswith('27') or col.startswith('26'))]]

covariates_df = covariates_df.merge(imaging_only, on='eid', how='inner').merge(ct_df, on='eid', how='inner')

# %%
covariates_df
# Out:
#            eid      bmi       mdi  education_years  curr_age  31-0.0  e2/e2  \
# 0      1000046  27.0842  25.37000              NaN      54.0     1.0      0
# 1      1000304  42.3268  23.00000             18.0      76.0     1.0      0
# 2      1000396  24.4995   7.59000             16.0      73.0     0.0      0
# 3      1000595  32.3960   4.25000              NaN      73.0     1.0      0
# 4      1000697  28.3025  35.61000              NaN      75.0     1.0      0
# ...        ...      ...       ...              ...       ...     ...    ...
# 42627  6024731  27.4406   3.76000             16.0      66.0     1.0      0
# 42628  6024757  30.3210   6.12541             17.0      72.0     1.0      0
# 42629  6025079  27.5938   7.61000             15.0      77.0     1.0      0
# 42630  6025128  25.9281   6.82000              NaN      62.0     1.0      0
# 42631  6025202  26.5909  25.17000              NaN      66.0     1.0      0
#
#        e3/e3  e2/e3  e3/e4  ...  25755_2_0_50  25755_2_0_51  25755_2_0_52  \
# 0          0      0      0  ...      0.740887      0.862363      0.878685
# 1          1      0      0  ...      0.595000      0.683000      0.743000
# 2          0      1      0  ...      0.506706      0.665595      0.636133
# 3          1      0      0  ...      0.640476      0.863235      0.638880
# 4          1      0      0  ...      0.637000      0.684000      0.799000
# ...      ...    ...    ...  ...           ...           ...           ...
# 42627      1      0      0  ...      0.643735      0.859428      0.783996
# 42628      1      0      0  ...      0.601686      0.555240      0.542795
# 42629      1      0      0  ...           NaN           NaN           NaN
# 42630      1      0      0  ...      0.596681      0.561190      0.714659
# 42631      1      0      0  ...      0.789402      0.880679      0.834984
#
#        25755_2_0_53  25755_2_0_54  25755_2_0_55  4282-2.0  20016-2.0  \
# 0          0.913898      0.746185      0.557628       7.0        9.0
# 1          0.587000      0.671000      0.480000       NaN        7.0
# 2          0.592260      0.562239      0.462905       7.0       11.0
# 3          0.634676      0.636426      0.601487       9.0       11.0
# 4          0.503000      0.710000      0.476000       NaN        NaN
# ...             ...           ...           ...       ...        ...
# 42627      0.714896      0.729920      0.535485       NaN        5.0
# 42628      0.657828      0.543537      0.395114       6.0        8.0
# 42629           NaN           NaN           NaN       NaN        7.0
# 42630      0.701322      0.576395      0.483037       7.0       10.0
# 42631      0.647501      0.785120      0.589414       NaN        7.0
#
#        20023-2.0  20197-2.0
# 0          406.0        7.0
# 1          526.0        NaN
# 2          550.0        7.0
# 3          584.0        4.0
# 4          632.0        NaN
# ...          ...        ...
# 42627      562.0        NaN
# 42628      499.0        3.0
# 42629      530.0        NaN
# 42630      507.0        6.0
# 42631      557.0        NaN
#
# [42632 rows x 3962 columns]

# %%
from econml.dml import CausalForestDML
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from lightgbm import LGBMRegressor
from doubleml_utils import run_dml
from econml.iv.dml import DMLIV

results = {}
cates = {}

covariates_df.dropna(subset = ['bmi', 'curr_age', '31-0.0', 'groups', 'education_years', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4'], inplace=True)

#sig_results['Imaging Metric'].unique().tolist()

for i in imaging_only.drop(columns=['eid']).columns.tolist()[0:1]:
    print(f"Processing imaging metric: {i}")
    valid_mask = ~covariates_df[i].isna()
    covariates_df = covariates_df[valid_mask]

    results[i] = {}
    cates[i] = {}

    for test in ['4282-2.0', '20016-2.0', '20023-2.0', '20197-2.0']:
        print('starting test')

        valid_mask = ~covariates_df[test].isna()
        covariates_df = covariates_df[valid_mask]

        Y = covariates_df[test]
        T = covariates_df[i]
        X = covariates_df[['bmi', 'mdi', 'curr_age', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4', 'education_years']]
        Z = covariates_df['31-0.0']

        print(Y.isna().sum(), T.isna().sum(), X.isna().sum(), Z.isna().sum())

        print(f"Fitting model for {i} and {test} with {len(Y)} samples")
        # DML with forest-based CATE estimator
        model = DMLIV(
            model_y_xw=LGBMRegressor(),
            model_t_xw=LGBMRegressor(),
            model_t_xwz=LGBMRegressor(),
            discrete_treatment=False,
            discrete_instrument=True,
            random_state=42
        )
        model.fit(Y, T, Z=Z, X=X)

        # Estimate overall ATE
        ate = model.ate(X)
        results[i][test] = {"ATE": ate, "model": model, "summary": model.summary}

        # Estimate CATEs
        cate = model.effect(X)
        cates[i][test] = cate
# Out:
# Processing imaging metric: 25000-2.0
# starting test
# 0 0 bmi                0
# mdi                0
# curr_age           0
# e2/e2              0
# e3/e3              0
# e2/e3              0
# e3/e4              0
# e2/e4              0
# e4/e4              0
# education_years    0
# dtype: int64 0
# Fitting model for 25000-2.0 and 4282-2.0 with 14705 samples
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003905 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 579
# [LightGBM] [Info] Number of data points in the train set: 7352, number of used features: 10
# [LightGBM] [Info] Start training from score 6.445185
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000080 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 579
# [LightGBM] [Info] Number of data points in the train set: 7352, number of used features: 10
# [LightGBM] [Info] Start training from score 1.305124
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 581
# [LightGBM] [Info] Number of data points in the train set: 7352, number of used features: 11
# [LightGBM] [Info] Start training from score 1.305124
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000238 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 582
# [LightGBM] [Info] Number of data points in the train set: 7353, number of used features: 10
# [LightGBM] [Info] Start training from score 6.433701
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000077 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 582
# [LightGBM] [Info] Number of data points in the train set: 7353, number of used features: 10
# [LightGBM] [Info] Start training from score 1.308345
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000103 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 7353, number of used features: 11
# [LightGBM] [Info] Start training from score 1.308345
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/sklearn_extensions/linear_model.py:1815: UserWarning: Co-variance matrix is underdetermined. Inference will be invalid!
#   warnings.warn("Co-variance matrix is underdetermined. Inference will be invalid!")
# starting test
# 0 0 bmi                0
# mdi                0
# curr_age           0
# e2/e2              0
# e3/e3              0
# e2/e3              0
# e3/e4              0
# e2/e4              0
# e4/e4              0
# education_years    0
# dtype: int64 0
# Fitting model for 25000-2.0 and 20016-2.0 with 14505 samples
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 7252, number of used features: 10
# [LightGBM] [Info] Start training from score 5.944291
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 7252, number of used features: 10
# [LightGBM] [Info] Start training from score 1.305838
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 582
# [LightGBM] [Info] Number of data points in the train set: 7252, number of used features: 11
# [LightGBM] [Info] Start training from score 1.305838
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 579
# [LightGBM] [Info] Number of data points in the train set: 7253, number of used features: 10
# [LightGBM] [Info] Start training from score 5.928995
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 579
# [LightGBM] [Info] Number of data points in the train set: 7253, number of used features: 10
# [LightGBM] [Info] Start training from score 1.307366
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 581
# [LightGBM] [Info] Number of data points in the train set: 7253, number of used features: 11
# [LightGBM] [Info] Start training from score 1.307366
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/sklearn_extensions/linear_model.py:1815: UserWarning: Co-variance matrix is underdetermined. Inference will be invalid!
#   warnings.warn("Co-variance matrix is underdetermined. Inference will be invalid!")
# starting test
# 0 0 bmi                0
# mdi                0
# curr_age           0
# e2/e2              0
# e3/e3              0
# e2/e3              0
# e3/e4              0
# e2/e4              0
# e4/e4              0
# education_years    0
# dtype: int64 0
# Fitting model for 25000-2.0 and 20023-2.0 with 14463 samples
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000090 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 581
# [LightGBM] [Info] Number of data points in the train set: 7231, number of used features: 10
# [LightGBM] [Info] Start training from score 607.509197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000080 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 581
# [LightGBM] [Info] Number of data points in the train set: 7231, number of used features: 10
# [LightGBM] [Info] Start training from score 1.306050
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 583
# [LightGBM] [Info] Number of data points in the train set: 7231, number of used features: 11
# [LightGBM] [Info] Start training from score 1.306050
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000080 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 7232, number of used features: 10
# [LightGBM] [Info] Start training from score 606.070658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 7232, number of used features: 10
# [LightGBM] [Info] Start training from score 1.307044
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 582
# [LightGBM] [Info] Number of data points in the train set: 7232, number of used features: 11
# [LightGBM] [Info] Start training from score 1.307044
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/sklearn_extensions/linear_model.py:1815: UserWarning: Co-variance matrix is underdetermined. Inference will be invalid!
#   warnings.warn("Co-variance matrix is underdetermined. Inference will be invalid!")
# starting test
# 0 0 bmi                0
# mdi                0
# curr_age           0
# e2/e2              0
# e3/e3              0
# e2/e3              0
# e3/e4              0
# e2/e4              0
# e4/e4              0
# education_years    0
# dtype: int64 0
# Fitting model for 25000-2.0 and 20197-2.0 with 14095 samples
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000076 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 581
# [LightGBM] [Info] Number of data points in the train set: 7047, number of used features: 10
# [LightGBM] [Info] Start training from score 6.498652
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 581
# [LightGBM] [Info] Number of data points in the train set: 7047, number of used features: 10
# [LightGBM] [Info] Start training from score 1.307967
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 583
# [LightGBM] [Info] Number of data points in the train set: 7047, number of used features: 11
# [LightGBM] [Info] Start training from score 1.307967
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000076 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 7048, number of used features: 10
# [LightGBM] [Info] Start training from score 6.418417
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 7048, number of used features: 10
# [LightGBM] [Info] Start training from score 1.305806
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 582
# [LightGBM] [Info] Number of data points in the train set: 7048, number of used features: 11
# [LightGBM] [Info] Start training from score 1.305806
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /home/heq754/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/sklearn_extensions/linear_model.py:1815: UserWarning: Co-variance matrix is underdetermined. Inference will be invalid!
#   warnings.warn("Co-variance matrix is underdetermined. Inference will be invalid!")

# %%
from doubleml_utils import flatten_imaging_cog_dict
cates
# Out:
# {'25000-2.0': {'4282-2.0': array([-1.45894769, -2.2076063 , -2.2338543 , ..., -1.93178068,
#          -1.09500744, -1.48103789], shape=(14705,)),
#   '20016-2.0': array([-1.49986346, -0.62521354, -0.33209268, ..., -1.89840956,
#          -1.21653565, -1.26566607], shape=(14505,)),
#   '20023-2.0': array([ 91.8760311 , 150.76354124, 105.40524106, ..., 129.69078513,
#          155.61218934, 161.38172793], shape=(14463,)),
#   '20197-2.0': array([4.62697062, 6.97858383, 7.59685536, ..., 4.68711958, 4.46187395,
#          4.77039202], shape=(14095,))}}

# %%
def cates_to_dataframe(cates_dict):
    """
    Convert nested dict of CATEs to a DataFrame.
    Structure: {imaging_metric: {cognitive_test: array, ...}, ...}
    """
    all_data = []
    
    for imaging_metric, cog_tests in cates_dict.items():
        for cog_test, cate_array in cog_tests.items():
            # Create a DataFrame for this combination
            temp_df = pd.DataFrame({
                'imaging_metric': imaging_metric,
                'cognitive_test': cog_test,
                'cate_value': cate_array,
                'subject_id': range(len(cate_array))  # Add subject identifier
            })
            all_data.append(temp_df)
    
    # Concatenate all DataFrames
    final_df = pd.concat(all_data, ignore_index=True)
    return final_df

# Convert your cates to DataFrame
cates_df = cates_to_dataframe(cates)
print(f"Shape: {cates_df.shape}")
print(cates_df.head(10))

df_fixed = cates_to_dataframe(cates)
# Out:
# Warning: Arrays have different lengths: {14705, 14505, 14095, 14463}
# Using minimum length: 14095
# Shape: (14095, 5)
#    subject_id  25000-2.0_4282-2.0  25000-2.0_20016-2.0  25000-2.0_20023-2.0  \
# 0           0           -1.458948            -1.499863            91.876031
# 1           1           -2.207606            -0.625214           150.763541
# 2           2           -2.233854            -0.332093           105.405241
# 3           3           -1.230764             1.095169           138.599142
# 4           4           -1.877043             0.139148           298.275979
#
#    25000-2.0_20197-2.0
# 0             4.626971
# 1             6.978584
# 2             7.596855
# 3             6.842732
# 4             4.466952
# Warning: Arrays have different lengths: {14705, 14505, 14095, 14463}
# Using minimum length: 14095

# %%
import pandas as pd
import glob

import pandas as pd
import glob

def merge_large_csvs_to_parquet(pattern, output_file, chunksize=10000):
    """
    Memory-efficient merging for very large CSV files, saving as parquet
    """
    csv_files = sorted(glob.glob(pattern))
    
    all_chunks = []
    
    for file in csv_files:
        fold_num = file.split('_')[-1].replace('.csv', '')
        
        # Read file in chunks
        for chunk in pd.read_csv(file, chunksize=chunksize):
            chunk['fold'] = int(fold_num)
            all_chunks.append(chunk)
    
    # Concatenate all chunks and save as parquet
    final_df = pd.concat(all_chunks, ignore_index=True)
    final_df.to_parquet(output_file, engine='fastparquet', index=False)
    
    print(f"Merged {len(csv_files)} files to {output_file}")
    print(f"Final DataFrame shape: {final_df.shape}")

# Usage
pattern = 'double_ml/imaging/results/imaging_to_cog/cates/cates_imaging_to_cogtest_fold_*.csv'
merge_large_csvs_to_parquet(pattern, 'double_ml/imaging/results/imaging_to_cog/cates/merged_results.parquet', chunksize=10000)
# Out:
# Merged 79 files to double_ml/imaging/results/imaging_to_cog/cates/merged_results.parquet
# Final DataFrame shape: (217178940, 5)

# %% [markdown]
# Analyzing Cates

# %%
import pandas as pd
df = pd.read_csv('double_ml/imaging/results/imaging_to_cog/cates/cates_imaging_to_cogtest_fold_0.csv', nrows = 14705)

# %%
df
# Out:
#       imaging_metric cognitive_test  cate_value  subject_id
# 0          25000-2.0       4282-2.0   -1.458948           0
# 1          25000-2.0       4282-2.0   -2.207606           1
# 2          25000-2.0       4282-2.0   -2.233854           2
# 3          25000-2.0       4282-2.0   -1.230764           3
# 4          25000-2.0       4282-2.0   -1.877043           4
# ...              ...            ...         ...         ...
# 14700      25000-2.0       4282-2.0   -0.684127       14700
# 14701      25000-2.0       4282-2.0   -1.280907       14701
# 14702      25000-2.0       4282-2.0   -1.931781       14702
# 14703      25000-2.0       4282-2.0   -1.095007       14703
# 14704      25000-2.0       4282-2.0   -1.481038       14704
#
# [14705 rows x 4 columns]

# %% [markdown]
# ## LGBM on CATES - obtaining feature importances
# Using LGBM to extract feature importances of demographics while predicting on CATES

# %%
from cates_utils import load_cates_3d_array
cates_array, imaging_metrics, cognitive_tests, n_patients = load_cates_3d_array('double_ml/imaging/results/imaging_to_cog/cates/cates_3d_array.npz')
# Out:
# Loaded 3D CATE array from double_ml/imaging/results/imaging_to_cog/cates/cates_3d_array.npz
# Array shape: (14864, 3945, 4)
# Imaging metrics: 3945
# Cognitive tests: 4
# Patients: 14864

# %%
imaging_metrics
# Out:
# ['25000-2.0',
#  '25001-2.0',
#  '25002-2.0',
#  '25003-2.0',
#  '25004-2.0',
#  '25005-2.0',
#  '25006-2.0',
#  '25007-2.0',
#  '25008-2.0',
#  '25009-2.0',
#  '25010-2.0',
#  '25011-2.0',
#  '25012-2.0',
#  '25013-2.0',
#  '25014-2.0',
#  '25015-2.0',
#  '25016-2.0',
#  '25017-2.0',
#  '25018-2.0',
#  '25019-2.0',
#  '25020-2.0',
#  '25021-2.0',
#  '25022-2.0',
#  '25023-2.0',
#  '25024-2.0',
#  '25025-2.0',
#  '25026-2.0',
#  '25027-2.0',
#  '25028-2.0',
#  '25029-2.0',
#  '25030-2.0',
#  '25031-2.0',
#  '25032-2.0',
#  '25033-2.0',
#  '25034-2.0',
#  '25035-2.0',
#  '25036-2.0',
#  '25037-2.0',
#  '25038-2.0',
#  '25039-2.0',
#  '25040-2.0',
#  '25042-2.0',
#  '25044-2.0',
#  '25046-2.0',
#  '25048-2.0',
#  '25050-2.0',
#  '25052-2.0',
#  '25054-2.0',
#  '25056-2.0',
#  '25057-2.0',
#  '25058-2.0',
#  '25059-2.0',
#  '25060-2.0',
#  '25061-2.0',
#  '25062-2.0',
#  '25063-2.0',
#  '25064-2.0',
#  '25065-2.0',
#  '25066-2.0',
#  '25067-2.0',
#  '25068-2.0',
#  '25069-2.0',
#  '25070-2.0',
#  '25071-2.0',
#  '25072-2.0',
#  '25073-2.0',
#  '25074-2.0',
#  '25075-2.0',
#  '25076-2.0',
#  '25077-2.0',
#  '25078-2.0',
#  '25079-2.0',
#  '25080-2.0',
#  '25081-2.0',
#  '25082-2.0',
#  '25083-2.0',
#  '25084-2.0',
#  '25085-2.0',
#  '25086-2.0',
#  '25087-2.0',
#  '25088-2.0',
#  '25089-2.0',
#  '25090-2.0',
#  '25091-2.0',
#  '25092-2.0',
#  '25093-2.0',
#  '25094-2.0',
#  '25095-2.0',
#  '25096-2.0',
#  '25097-2.0',
#  '25098-2.0',
#  '25099-2.0',
#  '25100-2.0',
#  '25101-2.0',
#  '25102-2.0',
#  '25103-2.0',
#  '25104-2.0',
#  '25105-2.0',
#  '25106-2.0',
#  '25107-2.0',
#  '25108-2.0',
#  '25109-2.0',
#  '25110-2.0',
#  '25111-2.0',
#  '25112-2.0',
#  '25113-2.0',
#  '25114-2.0',
#  '25115-2.0',
#  '25116-2.0',
#  '25117-2.0',
#  '25118-2.0',
#  '25119-2.0',
#  '25120-2.0',
#  '25121-2.0',
#  '25122-2.0',
#  '25123-2.0',
#  '25124-2.0',
#  '25125-2.0',
#  '25126-2.0',
#  '25127-2.0',
#  '25128-2.0',
#  '25129-2.0',
#  '25130-2.0',
#  '25131-2.0',
#  '25132-2.0',
#  '25133-2.0',
#  '25134-2.0',
#  '25135-2.0',
#  '25136-2.0',
#  '25137-2.0',
#  '25138-2.0',
#  '25139-2.0',
#  '25140-2.0',
#  '25141-2.0',
#  '25142-2.0',
#  '25143-2.0',
#  '25144-2.0',
#  '25145-2.0',
#  '25146-2.0',
#  '25147-2.0',
#  '25148-2.0',
#  '25149-2.0',
#  '25150-2.0',
#  '25151-2.0',
#  '25152-2.0',
#  '25153-2.0',
#  '25154-2.0',
#  '25155-2.0',
#  '25156-2.0',
#  '25157-2.0',
#  '25158-2.0',
#  '25159-2.0',
#  '25160-2.0',
#  '25161-2.0',
#  '25162-2.0',
#  '25163-2.0',
#  '25164-2.0',
#  '25165-2.0',
#  '25166-2.0',
#  '25167-2.0',
#  '25168-2.0',
#  '25169-2.0',
#  '25170-2.0',
#  '25171-2.0',
#  '25172-2.0',
#  '25173-2.0',
#  '25174-2.0',
#  '25175-2.0',
#  '25176-2.0',
#  '25177-2.0',
#  '25178-2.0',
#  '25179-2.0',
#  '25180-2.0',
#  '25181-2.0',
#  '25182-2.0',
#  '25183-2.0',
#  '25184-2.0',
#  '25185-2.0',
#  '25186-2.0',
#  '25187-2.0',
#  '25188-2.0',
#  '25189-2.0',
#  '25190-2.0',
#  '25191-2.0',
#  '25192-2.0',
#  '25193-2.0',
#  '25194-2.0',
#  '25195-2.0',
#  '25196-2.0',
#  '25197-2.0',
#  '25198-2.0',
#  '25199-2.0',
#  '25200-2.0',
#  '25201-2.0',
#  '25202-2.0',
#  '25203-2.0',
#  '25204-2.0',
#  '25205-2.0',
#  '25206-2.0',
#  '25207-2.0',
#  '25208-2.0',
#  '25209-2.0',
#  '25210-2.0',
#  '25211-2.0',
#  '25212-2.0',
#  '25213-2.0',
#  '25214-2.0',
#  '25215-2.0',
#  '25216-2.0',
#  '25217-2.0',
#  '25218-2.0',
#  '25219-2.0',
#  '25220-2.0',
#  '25221-2.0',
#  '25222-2.0',
#  '25223-2.0',
#  '25224-2.0',
#  '25225-2.0',
#  '25226-2.0',
#  '25227-2.0',
#  '25228-2.0',
#  '25229-2.0',
#  '25230-2.0',
#  '25231-2.0',
#  '25232-2.0',
#  '25233-2.0',
#  '25234-2.0',
#  '25235-2.0',
#  '25236-2.0',
#  '25237-2.0',
#  '25238-2.0',
#  '25239-2.0',
#  '25240-2.0',
#  '25241-2.0',
#  '25242-2.0',
#  '25243-2.0',
#  '25244-2.0',
#  '25245-2.0',
#  '25246-2.0',
#  '25247-2.0',
#  '25248-2.0',
#  '25249-2.0',
#  '25250-2.0',
#  '25251-2.0',
#  '25252-2.0',
#  '25253-2.0',
#  '25254-2.0',
#  '25255-2.0',
#  '25256-2.0',
#  '25257-2.0',
#  '25258-2.0',
#  '25259-2.0',
#  '25260-2.0',
#  '25261-2.0',
#  '25262-2.0',
#  '25263-2.0',
#  '25264-2.0',
#  '25265-2.0',
#  '25266-2.0',
#  '25267-2.0',
#  '25268-2.0',
#  '25269-2.0',
#  '25270-2.0',
#  '25271-2.0',
#  '25272-2.0',
#  '25273-2.0',
#  '25274-2.0',
#  '25275-2.0',
#  '25276-2.0',
#  '25277-2.0',
#  '25278-2.0',
#  '25279-2.0',
#  '25280-2.0',
#  '25281-2.0',
#  '25282-2.0',
#  '25283-2.0',
#  '25284-2.0',
#  '25285-2.0',
#  '25286-2.0',
#  '25287-2.0',
#  '25288-2.0',
#  '25289-2.0',
#  '25290-2.0',
#  '25291-2.0',
#  '25292-2.0',
#  '25293-2.0',
#  '25294-2.0',
#  '25295-2.0',
#  '25296-2.0',
#  '25297-2.0',
#  '25298-2.0',
#  '25299-2.0',
#  '25300-2.0',
#  '25301-2.0',
#  '25302-2.0',
#  '25303-2.0',
#  '25304-2.0',
#  '25305-2.0',
#  '25306-2.0',
#  '25307-2.0',
#  '25308-2.0',
#  '25309-2.0',
#  '25310-2.0',
#  '25311-2.0',
#  '25312-2.0',
#  '25313-2.0',
#  '25314-2.0',
#  '25315-2.0',
#  '25316-2.0',
#  '25317-2.0',
#  '25318-2.0',
#  '25319-2.0',
#  '25320-2.0',
#  '25321-2.0',
#  '25322-2.0',
#  '25323-2.0',
#  '25324-2.0',
#  '25325-2.0',
#  '25326-2.0',
#  '25327-2.0',
#  '25328-2.0',
#  '25329-2.0',
#  '25330-2.0',
#  '25331-2.0',
#  '25332-2.0',
#  '25333-2.0',
#  '25334-2.0',
#  '25335-2.0',
#  '25336-2.0',
#  '25337-2.0',
#  '25338-2.0',
#  '25339-2.0',
#  '25340-2.0',
#  '25341-2.0',
#  '25342-2.0',
#  '25343-2.0',
#  '25344-2.0',
#  '25345-2.0',
#  '25346-2.0',
#  '25347-2.0',
#  '25348-2.0',
#  '25349-2.0',
#  '25350-2.0',
#  '25351-2.0',
#  '25352-2.0',
#  '25353-2.0',
#  '25354-2.0',
#  '25355-2.0',
#  '25356-2.0',
#  '25357-2.0',
#  '25358-2.0',
#  '25359-2.0',
#  '25360-2.0',
#  '25361-2.0',
#  '25362-2.0',
#  '25363-2.0',
#  '25364-2.0',
#  '25365-2.0',
#  '25366-2.0',
#  '25367-2.0',
#  '25368-2.0',
#  '25369-2.0',
#  '25370-2.0',
#  '25371-2.0',
#  '25372-2.0',
#  '25373-2.0',
#  '25374-2.0',
#  '25375-2.0',
#  '25376-2.0',
#  '25377-2.0',
#  '25378-2.0',
#  '25379-2.0',
#  '25380-2.0',
#  '25381-2.0',
#  '25382-2.0',
#  '25383-2.0',
#  '25384-2.0',
#  '25385-2.0',
#  '25386-2.0',
#  '25387-2.0',
#  '25388-2.0',
#  '25389-2.0',
#  '25390-2.0',
#  '25391-2.0',
#  '25392-2.0',
#  '25393-2.0',
#  '25394-2.0',
#  '25395-2.0',
#  '25396-2.0',
#  '25397-2.0',
#  '25398-2.0',
#  '25399-2.0',
#  '25400-2.0',
#  '25401-2.0',
#  '25402-2.0',
#  '25403-2.0',
#  '25404-2.0',
#  '25405-2.0',
#  '25406-2.0',
#  '25407-2.0',
#  '25408-2.0',
#  '25409-2.0',
#  '25410-2.0',
#  '25411-2.0',
#  '25412-2.0',
#  '25413-2.0',
#  '25414-2.0',
#  '25415-2.0',
#  '25416-2.0',
#  '25417-2.0',
#  '25418-2.0',
#  '25419-2.0',
#  '25420-2.0',
#  '25421-2.0',
#  '25422-2.0',
#  '25423-2.0',
#  '25424-2.0',
#  '25425-2.0',
#  '25426-2.0',
#  '25427-2.0',
#  '25428-2.0',
#  '25429-2.0',
#  '25430-2.0',
#  '25431-2.0',
#  '25432-2.0',
#  '25433-2.0',
#  '25434-2.0',
#  '25435-2.0',
#  '25436-2.0',
#  '25437-2.0',
#  '25438-2.0',
#  '25439-2.0',
#  '25440-2.0',
#  '25441-2.0',
#  '25442-2.0',
#  '25443-2.0',
#  '25444-2.0',
#  '25445-2.0',
#  '25446-2.0',
#  '25447-2.0',
#  '25448-2.0',
#  '25449-2.0',
#  '25450-2.0',
#  '25451-2.0',
#  '25452-2.0',
#  '25453-2.0',
#  '25454-2.0',
#  '25455-2.0',
#  '25456-2.0',
#  '25457-2.0',
#  '25458-2.0',
#  '25459-2.0',
#  '25460-2.0',
#  '25461-2.0',
#  '25462-2.0',
#  '25463-2.0',
#  '25464-2.0',
#  '25465-2.0',
#  '25466-2.0',
#  '25467-2.0',
#  '25468-2.0',
#  '25469-2.0',
#  '25470-2.0',
#  '25471-2.0',
#  '25472-2.0',
#  '25473-2.0',
#  '25474-2.0',
#  '25475-2.0',
#  '25476-2.0',
#  '25477-2.0',
#  '25478-2.0',
#  '25479-2.0',
#  '25480-2.0',
#  '25481-2.0',
#  '25482-2.0',
#  '25483-2.0',
#  '25484-2.0',
#  '25485-2.0',
#  '25486-2.0',
#  '25487-2.0',
#  '25488-2.0',
#  '25489-2.0',
#  '25490-2.0',
#  '25491-2.0',
#  '25492-2.0',
#  '25493-2.0',
#  '25494-2.0',
#  '25495-2.0',
#  '25496-2.0',
#  '25497-2.0',
#  '25498-2.0',
#  '25499-2.0',
#  '25500-2.0',
#  '25501-2.0',
#  '25502-2.0',
#  '25503-2.0',
#  '25504-2.0',
#  '25505-2.0',
#  '25506-2.0',
#  '25507-2.0',
#  '25508-2.0',
#  '25509-2.0',
#  '25510-2.0',
#  '25511-2.0',
#  '25512-2.0',
#  '25513-2.0',
#  '25514-2.0',
#  '25515-2.0',
#  '25516-2.0',
#  '25517-2.0',
#  '25518-2.0',
#  '25519-2.0',
#  '25520-2.0',
#  '25521-2.0',
#  '25522-2.0',
#  '25523-2.0',
#  '25524-2.0',
#  '25525-2.0',
#  '25526-2.0',
#  '25527-2.0',
#  '25528-2.0',
#  '25529-2.0',
#  '25530-2.0',
#  '25531-2.0',
#  '25532-2.0',
#  '25533-2.0',
#  '25534-2.0',
#  '25535-2.0',
#  '25536-2.0',
#  '25537-2.0',
#  '25538-2.0',
#  '25539-2.0',
#  '25540-2.0',
#  '25541-2.0',
#  '25542-2.0',
#  '25543-2.0',
#  '25544-2.0',
#  '25545-2.0',
#  '25546-2.0',
#  '25547-2.0',
#  '25548-2.0',
#  '25549-2.0',
#  '25550-2.0',
#  '25551-2.0',
#  '25552-2.0',
#  '25553-2.0',
#  '25554-2.0',
#  '25555-2.0',
#  '25556-2.0',
#  '25557-2.0',
#  '25558-2.0',
#  '25559-2.0',
#  '25560-2.0',
#  '25561-2.0',
#  '25562-2.0',
#  '25563-2.0',
#  '25564-2.0',
#  '25565-2.0',
#  '25566-2.0',
#  '25567-2.0',
#  '25568-2.0',
#  '25569-2.0',
#  '25570-2.0',
#  '25571-2.0',
#  '25572-2.0',
#  '25573-2.0',
#  '25574-2.0',
#  '25575-2.0',
#  '25576-2.0',
#  '25577-2.0',
#  '25578-2.0',
#  '25579-2.0',
#  '25580-2.0',
#  '25581-2.0',
#  '25582-2.0',
#  '25583-2.0',
#  '25584-2.0',
#  '25585-2.0',
#  '25586-2.0',
#  '25587-2.0',
#  '25588-2.0',
#  '25589-2.0',
#  '25590-2.0',
#  '25591-2.0',
#  '25592-2.0',
#  '25593-2.0',
#  '25594-2.0',
#  '25595-2.0',
#  '25596-2.0',
#  '25597-2.0',
#  '25598-2.0',
#  '25599-2.0',
#  '25600-2.0',
#  '25601-2.0',
#  '25602-2.0',
#  '25603-2.0',
#  '25604-2.0',
#  '25605-2.0',
#  '25606-2.0',
#  '25607-2.0',
#  '25608-2.0',
#  '25609-2.0',
#  '25610-2.0',
#  '25611-2.0',
#  '25612-2.0',
#  '25613-2.0',
#  '25614-2.0',
#  '25615-2.0',
#  '25616-2.0',
#  '25617-2.0',
#  '25618-2.0',
#  '25619-2.0',
#  '25620-2.0',
#  '25621-2.0',
#  '25622-2.0',
#  '25623-2.0',
#  '25624-2.0',
#  '25625-2.0',
#  '25626-2.0',
#  '25627-2.0',
#  '25628-2.0',
#  '25629-2.0',
#  '25630-2.0',
#  '25631-2.0',
#  '25632-2.0',
#  '25633-2.0',
#  '25634-2.0',
#  '25635-2.0',
#  '25636-2.0',
#  '25637-2.0',
#  '25638-2.0',
#  '25639-2.0',
#  '25640-2.0',
#  '25641-2.0',
#  '25642-2.0',
#  '25643-2.0',
#  '25644-2.0',
#  '25645-2.0',
#  '25646-2.0',
#  '25647-2.0',
#  '25648-2.0',
#  '25649-2.0',
#  '25650-2.0',
#  '25651-2.0',
#  '25652-2.0',
#  '25653-2.0',
#  '25654-2.0',
#  '25655-2.0',
#  '25656-2.0',
#  '25657-2.0',
#  '25658-2.0',
#  '25659-2.0',
#  '25660-2.0',
#  '25661-2.0',
#  '25662-2.0',
#  '25663-2.0',
#  '25664-2.0',
#  '25665-2.0',
#  '25666-2.0',
#  '25667-2.0',
#  '25668-2.0',
#  '25669-2.0',
#  '25670-2.0',
#  '25671-2.0',
#  '25672-2.0',
#  '25673-2.0',
#  '25674-2.0',
#  '25675-2.0',
#  '25676-2.0',
#  '25677-2.0',
#  '25678-2.0',
#  '25679-2.0',
#  '25680-2.0',
#  '25681-2.0',
#  '25682-2.0',
#  '25683-2.0',
#  '25684-2.0',
#  '25685-2.0',
#  '25686-2.0',
#  '25687-2.0',
#  '25688-2.0',
#  '25689-2.0',
#  '25690-2.0',
#  '25691-2.0',
#  '25692-2.0',
#  '25693-2.0',
#  '25694-2.0',
#  '25695-2.0',
#  '25696-2.0',
#  '25697-2.0',
#  '25698-2.0',
#  '25699-2.0',
#  '25700-2.0',
#  '25701-2.0',
#  '25702-2.0',
#  '25703-2.0',
#  '25704-2.0',
#  '25705-2.0',
#  '25706-2.0',
#  '25707-2.0',
#  '25708-2.0',
#  '25709-2.0',
#  '25710-2.0',
#  '25711-2.0',
#  '25712-2.0',
#  '25713-2.0',
#  '25714-2.0',
#  '25715-2.0',
#  '25716-2.0',
#  '25717-2.0',
#  '25718-2.0',
#  '25719-2.0',
#  '25720-2.0',
#  '25721-2.0',
#  '25722-2.0',
#  '25723-2.0',
#  '25724-2.0',
#  '25725-2.0',
#  '25726-2.0',
#  '25727-2.0',
#  '25728-2.0',
#  '25729-2.0',
#  '25730-2.0',
#  '25731-2.0',
#  '25732-2.0',
#  '25733-2.0',
#  '25734-2.0',
#  '25735-2.0',
#  '25736-2.0',
#  '25737-2.0',
#  '25738-2.0',
#  '25739-2.0',
#  '25740-2.0',
#  '25741-2.0',
#  '25742-2.0',
#  '25743-2.0',
#  '25744-2.0',
#  '25745-2.0',
#  '25746-2.0',
#  '25752_2_0_1',
#  '25752_2_0_10',
#  '25752_2_0_100',
#  '25752_2_0_101',
#  '25752_2_0_102',
#  '25752_2_0_103',
#  '25752_2_0_104',
#  '25752_2_0_105',
#  '25752_2_0_106',
#  '25752_2_0_107',
#  '25752_2_0_108',
#  '25752_2_0_109',
#  '25752_2_0_11',
#  '25752_2_0_110',
#  '25752_2_0_111',
#  '25752_2_0_112',
#  '25752_2_0_113',
#  '25752_2_0_114',
#  '25752_2_0_115',
#  '25752_2_0_116',
#  '25752_2_0_117',
#  '25752_2_0_118',
#  '25752_2_0_119',
#  '25752_2_0_12',
#  '25752_2_0_120',
#  '25752_2_0_121',
#  '25752_2_0_122',
#  '25752_2_0_123',
#  '25752_2_0_124',
#  '25752_2_0_125',
#  '25752_2_0_126',
#  '25752_2_0_127',
#  '25752_2_0_128',
#  '25752_2_0_129',
#  '25752_2_0_13',
#  '25752_2_0_130',
#  '25752_2_0_131',
#  '25752_2_0_132',
#  '25752_2_0_133',
#  '25752_2_0_134',
#  '25752_2_0_135',
#  '25752_2_0_136',
#  '25752_2_0_137',
#  '25752_2_0_138',
#  '25752_2_0_139',
#  '25752_2_0_14',
#  '25752_2_0_140',
#  '25752_2_0_141',
#  '25752_2_0_142',
#  '25752_2_0_143',
#  '25752_2_0_144',
#  '25752_2_0_145',
#  '25752_2_0_146',
#  '25752_2_0_147',
#  '25752_2_0_148',
#  '25752_2_0_149',
#  '25752_2_0_15',
#  '25752_2_0_150',
#  '25752_2_0_151',
#  '25752_2_0_152',
#  '25752_2_0_153',
#  '25752_2_0_154',
#  '25752_2_0_155',
#  '25752_2_0_156',
#  '25752_2_0_157',
#  '25752_2_0_158',
#  '25752_2_0_159',
#  '25752_2_0_16',
#  '25752_2_0_160',
#  '25752_2_0_161',
#  '25752_2_0_162',
#  '25752_2_0_163',
#  '25752_2_0_164',
#  '25752_2_0_165',
#  '25752_2_0_166',
#  '25752_2_0_167',
#  '25752_2_0_168',
#  '25752_2_0_169',
#  '25752_2_0_17',
#  '25752_2_0_170',
#  '25752_2_0_171',
#  '25752_2_0_172',
#  '25752_2_0_173',
#  '25752_2_0_174',
#  '25752_2_0_175',
#  '25752_2_0_176',
#  '25752_2_0_177',
#  '25752_2_0_178',
#  '25752_2_0_179',
#  '25752_2_0_18',
#  '25752_2_0_180',
#  '25752_2_0_181',
#  '25752_2_0_182',
#  '25752_2_0_183',
#  '25752_2_0_184',
#  '25752_2_0_185',
#  '25752_2_0_186',
#  '25752_2_0_187',
#  '25752_2_0_188',
#  '25752_2_0_189',
#  '25752_2_0_19',
#  '25752_2_0_190',
#  '25752_2_0_191',
#  '25752_2_0_192',
#  '25752_2_0_193',
#  '25752_2_0_194',
#  '25752_2_0_195',
#  '25752_2_0_196',
#  '25752_2_0_197',
#  '25752_2_0_198',
#  '25752_2_0_199',
#  '25752_2_0_2',
#  '25752_2_0_20',
#  '25752_2_0_200',
#  '25752_2_0_201',
#  '25752_2_0_202',
#  '25752_2_0_203',
#  '25752_2_0_204',
#  '25752_2_0_205',
#  '25752_2_0_206',
#  '25752_2_0_207',
#  '25752_2_0_208',
#  '25752_2_0_209',
#  '25752_2_0_21',
#  '25752_2_0_210',
#  '25752_2_0_22',
#  '25752_2_0_23',
#  '25752_2_0_24',
#  '25752_2_0_25',
#  '25752_2_0_26',
#  '25752_2_0_27',
#  '25752_2_0_28',
#  '25752_2_0_29',
#  '25752_2_0_3',
#  '25752_2_0_30',
#  '25752_2_0_31',
#  '25752_2_0_32',
#  '25752_2_0_33',
#  '25752_2_0_34',
#  '25752_2_0_35',
#  '25752_2_0_36',
#  '25752_2_0_37',
#  '25752_2_0_38',
#  '25752_2_0_39',
#  '25752_2_0_4',
#  '25752_2_0_40',
#  '25752_2_0_41',
#  '25752_2_0_42',
#  '25752_2_0_43',
#  '25752_2_0_44',
#  '25752_2_0_45',
#  '25752_2_0_46',
#  '25752_2_0_47',
#  '25752_2_0_48',
#  '25752_2_0_49',
#  '25752_2_0_5',
#  '25752_2_0_50',
#  '25752_2_0_51',
#  '25752_2_0_52',
#  '25752_2_0_53',
#  '25752_2_0_54',
#  '25752_2_0_55',
#  '25752_2_0_56',
#  '25752_2_0_57',
#  '25752_2_0_58',
#  '25752_2_0_59',
#  '25752_2_0_6',
#  '25752_2_0_60',
#  '25752_2_0_61',
#  '25752_2_0_62',
#  '25752_2_0_63',
#  '25752_2_0_64',
#  '25752_2_0_65',
#  '25752_2_0_66',
#  '25752_2_0_67',
#  '25752_2_0_68',
#  '25752_2_0_69',
#  '25752_2_0_7',
#  '25752_2_0_70',
#  '25752_2_0_71',
#  '25752_2_0_72',
#  '25752_2_0_73',
#  '25752_2_0_74',
#  '25752_2_0_75',
#  '25752_2_0_76',
#  '25752_2_0_77',
#  '25752_2_0_78',
#  '25752_2_0_79',
#  '25752_2_0_8',
#  '25752_2_0_80',
#  '25752_2_0_81',
#  '25752_2_0_82',
#  '25752_2_0_83',
#  '25752_2_0_84',
#  '25752_2_0_85',
#  '25752_2_0_86',
#  '25752_2_0_87',
#  '25752_2_0_88',
#  '25752_2_0_89',
#  '25752_2_0_9',
#  '25752_2_0_90',
#  '25752_2_0_91',
#  '25752_2_0_92',
#  '25752_2_0_93',
#  '25752_2_0_94',
#  '25752_2_0_95',
#  '25752_2_0_96',
#  '25752_2_0_97',
#  '25752_2_0_98',
#  '25752_2_0_99',
#  '25753_2_0_1',
#  '25753_2_0_10',
#  '25753_2_0_100',
#  '25753_2_0_1000',
#  '25753_2_0_1001',
#  '25753_2_0_1002',
#  '25753_2_0_1003',
#  '25753_2_0_1004',
#  '25753_2_0_1005',
#  '25753_2_0_1006',
#  '25753_2_0_1007',
#  '25753_2_0_1008',
#  '25753_2_0_1009',
#  '25753_2_0_101',
#  '25753_2_0_1010',
#  '25753_2_0_1011',
#  '25753_2_0_1012',
#  '25753_2_0_1013',
#  '25753_2_0_1014',
#  '25753_2_0_1015',
#  '25753_2_0_1016',
#  '25753_2_0_1017',
#  '25753_2_0_1018',
#  '25753_2_0_1019',
#  '25753_2_0_102',
#  '25753_2_0_1020',
#  '25753_2_0_1021',
#  '25753_2_0_1022',
#  '25753_2_0_1023',
#  '25753_2_0_1024',
#  '25753_2_0_1025',
#  '25753_2_0_1026',
#  '25753_2_0_1027',
#  '25753_2_0_1028',
#  '25753_2_0_1029',
#  '25753_2_0_103',
#  '25753_2_0_1030',
#  '25753_2_0_1031',
#  '25753_2_0_1032',
#  '25753_2_0_1033',
#  '25753_2_0_1034',
#  '25753_2_0_1035',
#  '25753_2_0_1036',
#  '25753_2_0_1037',
#  '25753_2_0_1038',
#  '25753_2_0_1039',
#  '25753_2_0_104',
#  '25753_2_0_1040',
#  '25753_2_0_1041',
#  '25753_2_0_1042',
#  '25753_2_0_1043',
#  ...]

# %%
overlap_cog = ['4282-2.0', '20016-2.0', '20023-2.0', '20197-2.0']
covariates_df = pd.read_parquet('doubleML_covariates.parquet', engine='fastparquet', 
                               columns=['IID', 'bmi', 'mdi', 'education_years', 'curr_age', '31-0.0', 
                                      'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4', 'groups'])

covariates_df.dropna(subset = ['bmi', 'curr_age', '31-0.0', 'groups', 'education_years', 'e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4'], inplace=True)

covariates_df.rename(columns={'IID': 'eid'}, inplace=True)
ct_df = pd.read_parquet('cognitive_test_results_2.parquet', engine='fastparquet', 
                       columns=['eid'] + overlap_cog)

imaging_df = pd.read_parquet('../../../randy/rfb/tidy_data/UKBiobank/dementia/neuroimaging/X.parquet', engine='fastparquet')
imaging_only = imaging_df[['eid'] + [col for col in imaging_df.columns if (col.startswith('25') or col.startswith('27') or col.startswith('26'))]]

covariates_df = covariates_df.merge(imaging_only, on='eid', how='inner').merge(ct_df, on='eid', how='inner')

# %%
# Usage with the fixed function:
test_df = covariates_to_add_cates('4282-2.0', '25000-2.0', covariates_df, cates_array, imaging_metrics, cognitive_tests)
test_df
# Out:
# After filtering for 4282-2.0 and 25000-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
#            eid      bmi       mdi  curr_age  e2/e2  e3/e3  e2/e3  e3/e4  \
# 0      1000396  24.4995   7.59000      73.0      0      0      1      0
# 1      1000776  29.0941   3.14000      78.0      0      1      0      0
# 2      1000947  28.1909   4.09000      73.0      0      0      1      0
# 3      1001758  33.6916  43.10000      73.0      0      0      0      1
# 4      1002249  36.3119   9.96000      66.0      0      0      0      0
# ...        ...      ...       ...       ...    ...    ...    ...    ...
# 14700  6023450  24.7620  39.82000      64.0      0      1      0      0
# 14701  6023530  20.5191  23.00000      63.0      0      0      0      0
# 14702  6023611  22.2816  11.19000      70.0      0      0      0      1
# 14703  6024208  30.8845  14.25000      67.0      0      1      0      0
# 14704  6024757  30.3210   6.12541      72.0      0      1      0      0
#
#        e2/e4  e4/e4  education_years  4282-2.0  25000-2.0  cates_value
# 0          0      0             16.0       7.0    1.32265    -1.458948
# 1          0      0             21.0       5.0    1.49066    -2.207606
# 2          0      0             21.0       9.0    1.20067    -2.233854
# 3          0      0             17.0       8.0    1.18984    -1.230764
# 4          1      0             18.0       5.0    1.31902    -1.877043
# ...      ...    ...              ...       ...        ...          ...
# 14700      0      0             17.0       7.0    1.39307    -0.684127
# 14701      1      0             16.0       7.0    1.35110    -1.280907
# 14702      0      0             18.0       7.0    1.30279    -1.931781
# 14703      0      0             16.0       5.0    1.39270    -1.095007
# 14704      0      0             17.0       6.0    1.10583    -1.481038
#
# [14705 rows x 14 columns]

# %%
# If you want to analyze multiple imaging metrics and cognitive tests
import pandas as pd
from IPython.display import display

def analyze_cates_by_education_tertiles(cog, img, covariates_df, cates_array, imaging_metrics, cognitive_tests):
    """
    Analyze CATE values by education tertiles for a specific cognitive test and imaging metric.
    """
    # Get the data for this combination
    test_df = covariates_to_add_cates(cog, img, covariates_df, cates_array, imaging_metrics, cognitive_tests)
    
    # Create education tertiles
    test_df['education_tert'] = pd.qcut(test_df['education_years'], q=3, labels=['low', 'mid', 'high'])
    
    # Compute summary statistics
    summary = test_df.groupby('education_tert').agg({
        'cates_value': ['mean', 'std', 'count'],
        'education_years': ['mean', 'min', 'max']
    }).round(4)
    
    # Add metadata
    summary_flat = test_df.groupby('education_tert')['cates_value'].agg(['mean', 'std']).reset_index()
    summary_flat['imaging_metric'] = img
    summary_flat['cognitive_test'] = cog
    
    return summary, summary_flat

# Example usage for your specific case:
cog_test = '4282-2.0'
img_metric = '25000-2.0'

detailed_summary, simple_summary = analyze_cates_by_education_tertiles(
    cog_test, img_metric, covariates_df, cates_array, imaging_metrics, cognitive_tests
)

print(f"Analysis for {img_metric} → {cog_test}")
print("="*50)
display(detailed_summary)
print("\nSimple Summary:")
display(simple_summary)
# Out:
# After filtering for 4282-2.0 and 25000-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# Analysis for 25000-2.0 → 4282-2.0
# ==================================================
# /tmp/ipykernel_2875309/1224876456.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = test_df.groupby('education_tert').agg({
# /tmp/ipykernel_2875309/1224876456.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary_flat = test_df.groupby('education_tert')['cates_value'].agg(['mean', 'std']).reset_index()
#                cates_value               education_years
#                       mean     std count            mean   min   max
# education_tert
# low                -1.1440  0.3580  7630         15.6160  -2.0  16.0
# mid                -1.4393  0.3353  4367         17.5493  17.0  18.0
# high               -1.9765  0.4718  2708         21.2378  19.0  35.0
# Simple Summary:
#   education_tert      mean       std imaging_metric cognitive_test
# 0            low -1.143977  0.357985      25000-2.0       4282-2.0
# 1            mid -1.439279  0.335298      25000-2.0       4282-2.0
# 2           high -1.976501  0.471833      25000-2.0       4282-2.0

# %%
test_df
# Out:
#            eid      bmi       mdi  curr_age  e2/e2  e3/e3  e2/e3  e3/e4  \
# 0      1000396  24.4995   7.59000      73.0      0      0      1      0
# 1      1000776  29.0941   3.14000      78.0      0      1      0      0
# 2      1000947  28.1909   4.09000      73.0      0      0      1      0
# 3      1001758  33.6916  43.10000      73.0      0      0      0      1
# 4      1002536  28.4512  35.12000      63.0      0      0      0      1
# ...        ...      ...       ...       ...    ...    ...    ...    ...
# 13879  6023224  31.3291   7.61000      79.0      0      1      0      0
# 13880  6023450  24.7620  39.82000      64.0      0      1      0      0
# 13881  6023611  22.2816  11.19000      70.0      0      0      0      1
# 13882  6024208  30.8845  14.25000      67.0      0      1      0      0
# 13883  6024757  30.3210   6.12541      72.0      0      1      0      0
#
#        e2/e4  e4/e4  education_years  20197-2.0  25479-2.0  cates_value  \
# 0          0      0             16.0        7.0   0.127578   -38.814930
# 1          0      0             21.0        7.0   0.104432   -30.468605
# 2          0      0             21.0        6.0   0.285855   -43.155285
# 3          0      0             17.0        2.0   0.107248   -35.920963
# 4          0      0             15.0        6.0   0.066842   -34.431553
# ...      ...    ...              ...        ...        ...          ...
# 13879      0      0             15.0        0.0   0.073636          NaN
# 13880      0      0             17.0       10.0   0.078580          NaN
# 13881      0      0             18.0        7.0   0.073165          NaN
# 13882      0      0             16.0        7.0   0.076193          NaN
# 13883      0      0             17.0        3.0   0.228315          NaN
#
#       Education Level
# 0                   0
# 1                   1
# 2                   1
# 3                   1
# 4                   0
# ...               ...
# 13879               0
# 13880               1
# 13881               1
# 13882               0
# 13883               1
#
# [13884 rows x 15 columns]

# %%
from lightgbm import LGBMRegressor
X = test_df.drop(columns=['cates_value', 'eid', '4282-2.0', '25000-2.0'])
y = test_df['cates_value']
LGBM_model = LGBMRegressor()
LGBM_model.fit(X, y)

fi = LGBM_model.feature_importances_
fnames = LGBM_model.feature_name_

feature_importance_df = pd.DataFrame({'feature': fnames, 'importance': fi})
feature_importance_df.sort_values(by='importance', ascending=False, inplace=True)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 587
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 11
# [LightGBM] [Info] Start training from score -1.384988

# %%
feature_importance_df
# Out:
#             feature  importance
# 9   education_years         844
# 1               mdi         748
# 2          curr_age         650
# 0               bmi         177
# 6             e3/e4         168
# 7             e2/e4         132
# 4             e3/e3         124
# 8             e4/e4          82
# 3             e2/e2          44
# 5             e2/e3          31
# 10   education_tert           0

# %%
# implement LGBM 

from lightgbm import LGBMRegressor

feature_importances = {}

for i in imaging_metrics: 
    feature_importances[i] = {}
    for c in cognitive_tests:
        test_df = covariates_to_add_cates(c, i, covariates_df, cates_array, imaging_metrics, cognitive_tests)

        # fit
        X = test_df.drop(columns=['cates_value', 'eid', c, i])
        y = test_df['cates_value']

        LGBM_model = LGBMRegressor()
        LGBM_model.fit(X, y)

        # construct feature importances table
        fi = LGBM_model.feature_importances_
        fnames = LGBM_model.feature_name_

        feature_importance_df = pd.DataFrame({'feature': fnames, 'importance': fi})
        feature_importance_df.sort_values(by='importance', ascending=False, inplace=True)

        feature_importances[i][c] = feature_importance_df
# Out:
# After filtering for 20016-2.0 and 25000-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -1.280083
# After filtering for 20023-2.0 and 25000-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 128.644204
# After filtering for 20197-2.0 and 25000-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000455 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score 4.814271
# After filtering for 4282-2.0 and 25000-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score -1.384988
# After filtering for 20016-2.0 and 25001-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000474 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000007
# After filtering for 20023-2.0 and 25001-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000864
# After filtering for 20197-2.0 and 25001-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000030
# After filtering for 4282-2.0 and 25001-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000460 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000007
# After filtering for 20016-2.0 and 25002-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000005
# After filtering for 20023-2.0 and 25002-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000432
# After filtering for 20197-2.0 and 25002-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000017
# After filtering for 4282-2.0 and 25002-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000005
# After filtering for 20016-2.0 and 25003-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000017
# After filtering for 20023-2.0 and 25003-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001645
# After filtering for 20197-2.0 and 25003-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000062
# After filtering for 4282-2.0 and 25003-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000017
# After filtering for 20016-2.0 and 25004-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000016
# After filtering for 20023-2.0 and 25004-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001569
# After filtering for 20197-2.0 and 25004-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000058
# After filtering for 4282-2.0 and 25004-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000018
# After filtering for 20016-2.0 and 25005-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000471 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000007
# After filtering for 20023-2.0 and 25005-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000683
# After filtering for 20197-2.0 and 25005-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000023
# After filtering for 4282-2.0 and 25005-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000007
# After filtering for 20016-2.0 and 25006-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000004
# After filtering for 20023-2.0 and 25006-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000319
# After filtering for 20197-2.0 and 25006-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000013
# After filtering for 4282-2.0 and 25006-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000004
# After filtering for 20016-2.0 and 25007-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000007
# After filtering for 20023-2.0 and 25007-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000754
# After filtering for 20197-2.0 and 25007-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000030
# After filtering for 4282-2.0 and 25007-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000007
# After filtering for 20016-2.0 and 25008-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000003
# After filtering for 20023-2.0 and 25008-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000265
# After filtering for 20197-2.0 and 25008-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000010
# After filtering for 4282-2.0 and 25008-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000003
# After filtering for 20016-2.0 and 25009-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000003
# After filtering for 20023-2.0 and 25009-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000410
# After filtering for 20197-2.0 and 25009-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000015
# After filtering for 4282-2.0 and 25009-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000003
# After filtering for 20016-2.0 and 25010-2.0: 19862 rows
# CATE array subset length: 14864
# DataFrame length: 19862
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19862
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000002
# After filtering for 20023-2.0 and 25010-2.0: 20229 rows
# CATE array subset length: 14864
# DataFrame length: 20229
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20229
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000150
# After filtering for 20197-2.0 and 25010-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.000006
# After filtering for 4282-2.0 and 25010-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000002
# After filtering for 20016-2.0 and 25011-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000257
# After filtering for 20023-2.0 and 25011-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.028988
# After filtering for 20197-2.0 and 25011-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000442 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001112
# After filtering for 4282-2.0 and 25011-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000298
# After filtering for 20016-2.0 and 25012-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000269
# After filtering for 20023-2.0 and 25012-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.028067
# After filtering for 20197-2.0 and 25012-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000597 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001118
# After filtering for 4282-2.0 and 25012-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000301
# After filtering for 20016-2.0 and 25013-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000461 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000531
# After filtering for 20023-2.0 and 25013-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.049179
# After filtering for 20197-2.0 and 25013-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.002238
# After filtering for 4282-2.0 and 25013-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000446 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000667
# After filtering for 20016-2.0 and 25014-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000477 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000618
# After filtering for 20023-2.0 and 25014-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.049676
# After filtering for 20197-2.0 and 25014-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001998
# After filtering for 4282-2.0 and 25014-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000695
# After filtering for 20016-2.0 and 25015-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000323
# After filtering for 20023-2.0 and 25015-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.032800
# After filtering for 20197-2.0 and 25015-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001339
# After filtering for 4282-2.0 and 25015-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000386
# After filtering for 20016-2.0 and 25016-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000361
# After filtering for 20023-2.0 and 25016-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.032244
# After filtering for 20197-2.0 and 25016-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.001292
# After filtering for 4282-2.0 and 25016-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000383
# After filtering for 20016-2.0 and 25017-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000913
# After filtering for 20023-2.0 and 25017-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.114246
# After filtering for 20197-2.0 and 25017-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000442 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.004190
# After filtering for 4282-2.0 and 25017-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.001194
# After filtering for 20016-2.0 and 25018-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000921
# After filtering for 20023-2.0 and 25018-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.107306
# After filtering for 20197-2.0 and 25018-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000447 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.004295
# After filtering for 4282-2.0 and 25018-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.001087
# After filtering for 20016-2.0 and 25019-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000553
# After filtering for 20023-2.0 and 25019-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.059365
# After filtering for 20197-2.0 and 25019-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000146 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.002364
# After filtering for 4282-2.0 and 25019-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000726
# After filtering for 20016-2.0 and 25020-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000544
# After filtering for 20023-2.0 and 25020-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000454 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.062747
# After filtering for 20197-2.0 and 25020-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.002143
# After filtering for 4282-2.0 and 25020-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14705, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000630
# After filtering for 20016-2.0 and 25021-2.0: 19854 rows
# CATE array subset length: 14864
# DataFrame length: 19854
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19854
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 0.000972
# After filtering for 20023-2.0 and 25021-2.0: 20220 rows
# CATE array subset length: 14864
# DataFrame length: 20220
# WARNING: Length mismatch! CATE: 14864, DataFrame: 20220
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -0.114160
# After filtering for 20197-2.0 and 25021-2.0: 14335 rows
# CATE array subset length: 14335
# DataFrame length: 14335
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14335, number of used features: 10
# [LightGBM] [Info] Start training from score -0.004169
# After filtering for 4282-2.0 and 25021-2.0: 14705 rows
# CATE array subset length: 14705
# DataFrame length: 14705
# ...
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -2241.578086
# After filtering for 20197-2.0 and 25473-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -45.105446
# After filtering for 4282-2.0 and 25473-2.0: 14208 rows
# CATE array subset length: 14208
# DataFrame length: 14208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14208, number of used features: 10
# [LightGBM] [Info] Start training from score 5.768048
# After filtering for 20016-2.0 and 25474-2.0: 18840 rows
# CATE array subset length: 14864
# DataFrame length: 18840
# WARNING: Length mismatch! CATE: 14864, DataFrame: 18840
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 12.241500
# After filtering for 20023-2.0 and 25474-2.0: 19176 rows
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -1294.214235
# After filtering for 20197-2.0 and 25474-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -49.482391
# After filtering for 4282-2.0 and 25474-2.0: 14208 rows
# CATE array subset length: 14208
# DataFrame length: 14208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14208, number of used features: 10
# [LightGBM] [Info] Start training from score 20.346998
# After filtering for 20016-2.0 and 25475-2.0: 18840 rows
# CATE array subset length: 14864
# DataFrame length: 18840
# WARNING: Length mismatch! CATE: 14864, DataFrame: 18840
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 4.434392
# After filtering for 20023-2.0 and 25475-2.0: 19176 rows
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -817.482407
# After filtering for 20197-2.0 and 25475-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -44.910297
# After filtering for 4282-2.0 and 25475-2.0: 14208 rows
# CATE array subset length: 14208
# DataFrame length: 14208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14208, number of used features: 10
# [LightGBM] [Info] Start training from score -5.883256
# After filtering for 20016-2.0 and 25476-2.0: 18840 rows
# CATE array subset length: 14864
# DataFrame length: 18840
# WARNING: Length mismatch! CATE: 14864, DataFrame: 18840
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 20.771235
# After filtering for 20023-2.0 and 25476-2.0: 19176 rows
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -2343.130618
# After filtering for 20197-2.0 and 25476-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -94.202277
# After filtering for 4282-2.0 and 25476-2.0: 14208 rows
# CATE array subset length: 14208
# DataFrame length: 14208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14208, number of used features: 10
# [LightGBM] [Info] Start training from score 19.667940
# After filtering for 20016-2.0 and 25477-2.0: 18840 rows
# CATE array subset length: 14864
# DataFrame length: 18840
# WARNING: Length mismatch! CATE: 14864, DataFrame: 18840
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 18.636957
# After filtering for 20023-2.0 and 25477-2.0: 19176 rows
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -2086.842953
# After filtering for 20197-2.0 and 25477-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000978 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -66.477117
# After filtering for 4282-2.0 and 25477-2.0: 14208 rows
# CATE array subset length: 14208
# DataFrame length: 14208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14208, number of used features: 10
# [LightGBM] [Info] Start training from score 18.942899
# After filtering for 20016-2.0 and 25478-2.0: 18840 rows
# CATE array subset length: 14864
# DataFrame length: 18840
# WARNING: Length mismatch! CATE: 14864, DataFrame: 18840
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 11.237371
# After filtering for 20023-2.0 and 25478-2.0: 19176 rows
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -956.755256
# After filtering for 20197-2.0 and 25478-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -21.832848
# After filtering for 4282-2.0 and 25478-2.0: 14208 rows
# CATE array subset length: 14208
# DataFrame length: 14208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14208, number of used features: 10
# [LightGBM] [Info] Start training from score 9.014429
# After filtering for 20016-2.0 and 25479-2.0: 18840 rows
# CATE array subset length: 14864
# DataFrame length: 18840
# WARNING: Length mismatch! CATE: 14864, DataFrame: 18840
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score 10.190587
# After filtering for 20023-2.0 and 25479-2.0: 19176 rows
# CATE array subset length: 14864
# DataFrame length: 19176
# WARNING: Length mismatch! CATE: 14864, DataFrame: 19176
# Truncated both to length: 14864
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 14864, number of used features: 10
# [LightGBM] [Info] Start training from score -808.956916
# After filtering for 20197-2.0 and 25479-2.0: 13884 rows
# CATE array subset length: 13884
# DataFrame length: 13884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 584
# [LightGBM] [Info] Number of data points in the train set: 13884, number of used features: 10
# [LightGBM] [Info] Start training from score -32.344212
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 17
#      14 y = test_df['cates_value']
#      16 LGBM_model = LGBMRegressor()
# ---> 17 LGBM_model.fit(X, y)
#      19 # construct feature importances table
#      20 fi = LGBM_model.feature_importances_
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/lightgbm/sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)
#    1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# KeyboardInterrupt:

# %%
from doubleml_utils import merge_folds

df = merge_folds('imaging_to_cog', 'double_ml/imaging/results')

# %%
all_results = pd.read_csv('double_ml/imaging/results/imaging_to_cog/all_results.csv')

# %%
# Bonferroni-corrected threshold for 4 tests
alpha = 0.05 / 4

# Pivot to wide format: Imaging Metric as index, Cognitive Test columns, P>|t| as values
pvals = all_results.pivot(index='Imaging Metric', columns='Cognitive Test', values='P>|t|')

# Find imaging metrics where all 4 cognitive tests are significant
sig_metrics = pvals[(pvals[overlap_cog] < alpha).all(axis=1)].index.tolist()

# Filter all_results for these imaging metrics
sig_results = all_results[all_results['Imaging Metric'].isin(sig_metrics)]

sig_results
# Out:
#       Imaging Metric Cognitive Test         coef     std err          t  \
# 0          25000-2.0       4282-2.0    -1.287195    0.174328  -7.383756
# 1          25000-2.0      20016-2.0    -1.230470    0.205471  -5.988544
# 2          25000-2.0      20023-2.0   140.752507   11.751644  11.977261
# 3          25000-2.0      20197-2.0     5.404706    0.296206  18.246446
# 4          25001-2.0       4282-2.0    -0.000011    0.000001  -7.495370
# ...              ...            ...          ...         ...        ...
# 15775      25506-2.0      20197-2.0  -101.985230    7.974312 -12.789221
# 15776      25507-2.0       4282-2.0   -42.484014    6.542968  -6.493079
# 15777      25507-2.0      20016-2.0   -36.664368    7.542127  -4.861277
# 15778      25507-2.0      20023-2.0  4233.194934  533.811539   7.930130
# 15779      25507-2.0      20197-2.0   167.822114   16.971512   9.888460
#
#               P>|t|        2.5 %       97.5 %
# 0      1.538857e-13    -1.628871    -0.945518
# 1      2.117281e-09    -1.633185    -0.827755
# 2      4.675181e-33   117.719707   163.785306
# 3      2.208169e-74     4.824153     5.985259
# 4      6.611139e-14    -0.000014    -0.000008
# ...             ...          ...          ...
# 15775  1.883534e-37  -117.614593   -86.355866
# 15776  8.409931e-11   -55.307996   -29.660031
# 15777  1.166309e-06   -51.446665   -21.882071
# 15778  2.189165e-15  3186.943542  5279.446326
# 15779  4.671604e-23   134.558561   201.085666
#
# [12740 rows x 8 columns]

# %%
sig_results['Imaging Metric'].unique().tolist()
# Out:
# ['25000-2.0',
#  '25001-2.0',
#  '25002-2.0',
#  '25003-2.0',
#  '25004-2.0',
#  '25005-2.0',
#  '25006-2.0',
#  '25007-2.0',
#  '25008-2.0',
#  '25009-2.0',
#  '25010-2.0',
#  '25011-2.0',
#  '25012-2.0',
#  '25013-2.0',
#  '25014-2.0',
#  '25015-2.0',
#  '25016-2.0',
#  '25017-2.0',
#  '25018-2.0',
#  '25019-2.0',
#  '25020-2.0',
#  '25021-2.0',
#  '25022-2.0',
#  '25023-2.0',
#  '25024-2.0',
#  '25025-2.0',
#  '25026-2.0',
#  '25027-2.0',
#  '25028-2.0',
#  '25029-2.0',
#  '25030-2.0',
#  '25031-2.0',
#  '25032-2.0',
#  '25033-2.0',
#  '25034-2.0',
#  '25035-2.0',
#  '25036-2.0',
#  '25037-2.0',
#  '25039-2.0',
#  '25040-2.0',
#  '25042-2.0',
#  '25044-2.0',
#  '25046-2.0',
#  '25048-2.0',
#  '25050-2.0',
#  '25052-2.0',
#  '25054-2.0',
#  '25056-2.0',
#  '25059-2.0',
#  '25061-2.0',
#  '25062-2.0',
#  '25063-2.0',
#  '25064-2.0',
#  '25065-2.0',
#  '25066-2.0',
#  '25068-2.0',
#  '25069-2.0',
#  '25070-2.0',
#  '25071-2.0',
#  '25072-2.0',
#  '25073-2.0',
#  '25074-2.0',
#  '25075-2.0',
#  '25076-2.0',
#  '25078-2.0',
#  '25079-2.0',
#  '25080-2.0',
#  '25082-2.0',
#  '25083-2.0',
#  '25084-2.0',
#  '25085-2.0',
#  '25086-2.0',
#  '25087-2.0',
#  '25089-2.0',
#  '25090-2.0',
#  '25091-2.0',
#  '25092-2.0',
#  '25093-2.0',
#  '25095-2.0',
#  '25096-2.0',
#  '25100-2.0',
#  '25101-2.0',
#  '25102-2.0',
#  '25103-2.0',
#  '25104-2.0',
#  '25105-2.0',
#  '25106-2.0',
#  '25107-2.0',
#  '25510-2.0',
#  '25511-2.0',
#  '25512-2.0',
#  '25513-2.0',
#  '25514-2.0',
#  '25515-2.0',
#  '25516-2.0',
#  '25517-2.0',
#  '25518-2.0',
#  '25519-2.0',
#  '25520-2.0',
#  '25521-2.0',
#  '25522-2.0',
#  '25523-2.0',
#  '25526-2.0',
#  '25527-2.0',
#  '25528-2.0',
#  '25529-2.0',
#  '25530-2.0',
#  '25531-2.0',
#  '25532-2.0',
#  '25533-2.0',
#  '25534-2.0',
#  '25535-2.0',
#  '25540-2.0',
#  '25542-2.0',
#  '25544-2.0',
#  '25545-2.0',
#  '25546-2.0',
#  '25547-2.0',
#  '25548-2.0',
#  '25549-2.0',
#  '25550-2.0',
#  '25551-2.0',
#  '25552-2.0',
#  '25555-2.0',
#  '25556-2.0',
#  '25557-2.0',
#  '25558-2.0',
#  '25559-2.0',
#  '25560-2.0',
#  '25561-2.0',
#  '25562-2.0',
#  '25563-2.0',
#  '25564-2.0',
#  '25565-2.0',
#  '25566-2.0',
#  '25567-2.0',
#  '25568-2.0',
#  '25570-2.0',
#  '25571-2.0',
#  '25572-2.0',
#  '25573-2.0',
#  '25575-2.0',
#  '25576-2.0',
#  '25577-2.0',
#  '25578-2.0',
#  '25580-2.0',
#  '25581-2.0',
#  '25582-2.0',
#  '25583-2.0',
#  '25584-2.0',
#  '25585-2.0',
#  '25586-2.0',
#  '25587-2.0',
#  '25588-2.0',
#  '25589-2.0',
#  '25590-2.0',
#  '25591-2.0',
#  '25592-2.0',
#  '25593-2.0',
#  '25595-2.0',
#  '25596-2.0',
#  '25597-2.0',
#  '25598-2.0',
#  '25599-2.0',
#  '25600-2.0',
#  '25601-2.0',
#  '25602-2.0',
#  '25603-2.0',
#  '25604-2.0',
#  '25605-2.0',
#  '25608-2.0',
#  '25609-2.0',
#  '25610-2.0',
#  '25612-2.0',
#  '25613-2.0',
#  '25614-2.0',
#  '25615-2.0',
#  '25616-2.0',
#  '25617-2.0',
#  '25618-2.0',
#  '25619-2.0',
#  '25620-2.0',
#  '25621-2.0',
#  '25623-2.0',
#  '25624-2.0',
#  '25626-2.0',
#  '25627-2.0',
#  '25628-2.0',
#  '25629-2.0',
#  '25631-2.0',
#  '25632-2.0',
#  '25635-2.0',
#  '25636-2.0',
#  '25637-2.0',
#  '25638-2.0',
#  '25639-2.0',
#  '25640-2.0',
#  '25641-2.0',
#  '25642-2.0',
#  '25643-2.0',
#  '25644-2.0',
#  '25646-2.0',
#  '25647-2.0',
#  '25648-2.0',
#  '25651-2.0',
#  '25652-2.0',
#  '25654-2.0',
#  '25655-2.0',
#  '25656-2.0',
#  '25657-2.0',
#  '25658-2.0',
#  '25659-2.0',
#  '25660-2.0',
#  '25662-2.0',
#  '25663-2.0',
#  '25664-2.0',
#  '25665-2.0',
#  '25666-2.0',
#  '25667-2.0',
#  '25668-2.0',
#  '25669-2.0',
#  '25670-2.0',
#  '25671-2.0',
#  '25673-2.0',
#  '25674-2.0',
#  '25675-2.0',
#  '25676-2.0',
#  '25677-2.0',
#  '25678-2.0',
#  '25679-2.0',
#  '25680-2.0',
#  '25681-2.0',
#  '25682-2.0',
#  '25683-2.0',
#  '25684-2.0',
#  '25685-2.0',
#  '25686-2.0',
#  '25687-2.0',
#  '25688-2.0',
#  '25689-2.0',
#  '25690-2.0',
#  '25691-2.0',
#  '25692-2.0',
#  '25693-2.0',
#  '25694-2.0',
#  '25695-2.0',
#  '25696-2.0',
#  '25697-2.0',
#  '25698-2.0',
#  '25699-2.0',
#  '25700-2.0',
#  '25701-2.0',
#  '25702-2.0',
#  '25703-2.0',
#  '25705-2.0',
#  '25706-2.0',
#  '25707-2.0',
#  '25708-2.0',
#  '25709-2.0',
#  '25710-2.0',
#  '25711-2.0',
#  '25712-2.0',
#  '25714-2.0',
#  '25715-2.0',
#  '25719-2.0',
#  '25720-2.0',
#  '25723-2.0',
#  '25726-2.0',
#  '25727-2.0',
#  '25728-2.0',
#  '25730-2.0',
#  '25731-2.0',
#  '25732-2.0',
#  '25733-2.0',
#  '25734-2.0',
#  '25735-2.0',
#  '25736-2.0',
#  '25737-2.0',
#  '25738-2.0',
#  '25739-2.0',
#  '25740-2.0',
#  '25741-2.0',
#  '25742-2.0',
#  '25743-2.0',
#  '25744-2.0',
#  '25745-2.0',
#  '25746-2.0',
#  '25756-2.0',
#  '25757-2.0',
#  '25758-2.0',
#  '25761-2.0',
#  '25762-2.0',
#  '25764-2.0',
#  '25765-2.0',
#  '25768-2.0',
#  '25781-2.0',
#  '25782-2.0',
#  '25783-2.0',
#  '25784-2.0',
#  '25785-2.0',
#  '25786-2.0',
#  '25787-2.0',
#  '25788-2.0',
#  '25789-2.0',
#  '25790-2.0',
#  '25791-2.0',
#  '25792-2.0',
#  '25793-2.0',
#  '25794-2.0',
#  '25795-2.0',
#  '25796-2.0',
#  '25797-2.0',
#  '25798-2.0',
#  '25799-2.0',
#  '25800-2.0',
#  '25801-2.0',
#  '25802-2.0',
#  '25803-2.0',
#  '25804-2.0',
#  '25805-2.0',
#  '25806-2.0',
#  '25807-2.0',
#  '25808-2.0',
#  '25809-2.0',
#  '25810-2.0',
#  '25811-2.0',
#  '25812-2.0',
#  '25813-2.0',
#  '25814-2.0',
#  '25815-2.0',
#  '25816-2.0',
#  '25817-2.0',
#  '25818-2.0',
#  '25819-2.0',
#  '25820-2.0',
#  '25821-2.0',
#  '25822-2.0',
#  '25823-2.0',
#  '25824-2.0',
#  '25825-2.0',
#  '25826-2.0',
#  '25827-2.0',
#  '25828-2.0',
#  '25829-2.0',
#  '25830-2.0',
#  '25831-2.0',
#  '25832-2.0',
#  '25833-2.0',
#  '25834-2.0',
#  '25835-2.0',
#  '25836-2.0',
#  '25837-2.0',
#  '25838-2.0',
#  '25839-2.0',
#  '25840-2.0',
#  '25841-2.0',
#  '25842-2.0',
#  '25843-2.0',
#  '25844-2.0',
#  '25845-2.0',
#  '25846-2.0',
#  '25847-2.0',
#  '25848-2.0',
#  '25849-2.0',
#  '25850-2.0',
#  '25851-2.0',
#  '25852-2.0',
#  '25853-2.0',
#  '25854-2.0',
#  '25855-2.0',
#  '25856-2.0',
#  '25857-2.0',
#  '25858-2.0',
#  '25859-2.0',
#  '25860-2.0',
#  '25861-2.0',
#  '25862-2.0',
#  '25863-2.0',
#  '25864-2.0',
#  '25865-2.0',
#  '25866-2.0',
#  '25867-2.0',
#  '25868-2.0',
#  '25869-2.0',
#  '25870-2.0',
#  '25871-2.0',
#  '25872-2.0',
#  '25873-2.0',
#  '25874-2.0',
#  '25875-2.0',
#  '25876-2.0',
#  '25877-2.0',
#  '25878-2.0',
#  '25879-2.0',
#  '25880-2.0',
#  '25881-2.0',
#  '25882-2.0',
#  '25883-2.0',
#  '25885-2.0',
#  '25886-2.0',
#  '25887-2.0',
#  '25888-2.0',
#  '25889-2.0',
#  '25890-2.0',
#  '25891-2.0',
#  '25892-2.0',
#  '25893-2.0',
#  '25894-2.0',
#  '25895-2.0',
#  '25896-2.0',
#  '25897-2.0',
#  '25898-2.0',
#  '25899-2.0',
#  '25900-2.0',
#  '25902-2.0',
#  '25903-2.0',
#  '25904-2.0',
#  '25905-2.0',
#  '25906-2.0',
#  '25907-2.0',
#  '25908-2.0',
#  '25909-2.0',
#  '25910-2.0',
#  '25911-2.0',
#  '25912-2.0',
#  '25913-2.0',
#  '25914-2.0',
#  '25916-2.0',
#  '25918-2.0',
#  '25919-2.0',
#  '25920-2.0',
#  '26501-2.0',
#  '26502-2.0',
#  '26504-2.0',
#  '26505-2.0',
#  '26510-2.0',
#  '26512-2.0',
#  '26513-2.0',
#  '26514-2.0',
#  '26515-2.0',
#  '26516-2.0',
#  '26517-2.0',
#  '26518-2.0',
#  '26519-2.0',
#  '26520-2.0',
#  '26521-2.0',
#  '26522-2.0',
#  '26523-2.0',
#  '26524-2.0',
#  '26526-2.0',
#  '26527-2.0',
#  '26528-2.0',
#  '26530-2.0',
#  '26531-2.0',
#  '26532-2.0',
#  '26534-2.0',
#  '26535-2.0',
#  '26537-2.0',
#  '26538-2.0',
#  '26539-2.0',
#  '26540-2.0',
#  '26541-2.0',
#  '26542-2.0',
#  '26543-2.0',
#  '26544-2.0',
#  '26546-2.0',
#  '26547-2.0',
#  '26548-2.0',
#  '26549-2.0',
#  '26550-2.0',
#  '26551-2.0',
#  '26552-2.0',
#  '26553-2.0',
#  '26554-2.0',
#  '26555-2.0',
#  '26556-2.0',
#  '26557-2.0',
#  '26558-2.0',
#  '26559-2.0',
#  '26560-2.0',
#  '26561-2.0',
#  '26562-2.0',
#  '26563-2.0',
#  '26564-2.0',
#  '26565-2.0',
#  '26566-2.0',
#  '26567-2.0',
#  '26568-2.0',
#  '26569-2.0',
#  '26570-2.0',
#  '26571-2.0',
#  '26572-2.0',
#  '26573-2.0',
#  '26574-2.0',
#  '26575-2.0',
#  '26577-2.0',
#  '26578-2.0',
#  '26579-2.0',
#  '26580-2.0',
#  '26581-2.0',
#  '26582-2.0',
#  '26583-2.0',
#  '26584-2.0',
#  '26585-2.0',
#  '26586-2.0',
#  '26587-2.0',
#  '26588-2.0',
#  '26589-2.0',
#  '26590-2.0',
#  '26591-2.0',
#  '26592-2.0',
#  '26593-2.0',
#  '26594-2.0',
#  '26595-2.0',
#  '26596-2.0',
#  '26597-2.0',
#  '26598-2.0',
#  '25108-2.0',
#  '25109-2.0',
#  '25110-2.0',
#  '25111-2.0',
#  '25112-2.0',
#  '25113-2.0',
#  '25114-2.0',
#  '25115-2.0',
#  '25116-2.0',
#  '25117-2.0',
#  '25118-2.0',
#  '25119-2.0',
#  '25120-2.0',
#  '25123-2.0',
#  '25124-2.0',
#  '25125-2.0',
#  '25126-2.0',
#  '25127-2.0',
#  '25128-2.0',
#  '25129-2.0',
#  '25130-2.0',
#  '25131-2.0',
#  '25132-2.0',
#  '25133-2.0',
#  '25134-2.0',
#  '25135-2.0',
#  '25138-2.0',
#  '25139-2.0',
#  '25140-2.0',
#  '25142-2.0',
#  '25143-2.0',
#  '25145-2.0',
#  '25146-2.0',
#  '25147-2.0',
#  '25148-2.0',
#  '25149-2.0',
#  '25150-2.0',
#  '25152-2.0',
#  '25153-2.0',
#  '25154-2.0',
#  '25155-2.0',
#  '25156-2.0',
#  '25157-2.0',
#  '26599-2.0',
#  '26600-2.0',
#  '26601-2.0',
#  '26602-2.0',
#  '26603-2.0',
#  '26604-2.0',
#  '26605-2.0',
#  '26606-2.0',
#  '26607-2.0',
#  '26608-2.0',
#  '26609-2.0',
#  '26610-2.0',
#  '26611-2.0',
#  '26612-2.0',
#  '26613-2.0',
#  '26614-2.0',
#  '26615-2.0',
#  '26616-2.0',
#  '26617-2.0',
#  '26618-2.0',
#  '26619-2.0',
#  '26620-2.0',
#  '26621-2.0',
#  '26622-2.0',
#  '26623-2.0',
#  '26624-2.0',
#  '26625-2.0',
#  '26626-2.0',
#  '26627-2.0',
#  '26628-2.0',
#  '26629-2.0',
#  '26630-2.0',
#  '26631-2.0',
#  '26632-2.0',
#  '26633-2.0',
#  '26634-2.0',
#  '26635-2.0',
#  '26636-2.0',
#  '26637-2.0',
#  '26638-2.0',
#  '26639-2.0',
#  '26640-2.0',
#  '26641-2.0',
#  '26642-2.0',
#  '26643-2.0',
#  '26644-2.0',
#  '26645-2.0',
#  '26646-2.0',
#  '26647-2.0',
#  '26648-2.0',
#  '26649-2.0',
#  '26650-2.0',
#  '26651-2.0',
#  '26652-2.0',
#  '26653-2.0',
#  '26654-2.0',
#  '26655-2.0',
#  '26656-2.0',
#  '26657-2.0',
#  '26658-2.0',
#  '26659-2.0',
#  '26660-2.0',
#  '26661-2.0',
#  '26662-2.0',
#  '26663-2.0',
#  '26664-2.0',
#  '26665-2.0',
#  '26666-2.0',
#  '26667-2.0',
#  '26668-2.0',
#  '26669-2.0',
#  '26670-2.0',
#  '26671-2.0',
#  '26672-2.0',
#  '26673-2.0',
#  '26674-2.0',
#  '26675-2.0',
#  '26676-2.0',
#  '26677-2.0',
#  '26678-2.0',
#  '26679-2.0',
#  '26680-2.0',
#  '26681-2.0',
#  '26682-2.0',
#  '26683-2.0',
#  '26684-2.0',
#  '26685-2.0',
#  '26686-2.0',
#  '26687-2.0',
#  '26688-2.0',
#  '26689-2.0',
#  '26690-2.0',
#  '26691-2.0',
#  '26692-2.0',
#  '26693-2.0',
#  '26694-2.0',
#  '26695-2.0',
#  '26696-2.0',
#  '26697-2.0',
#  '26698-2.0',
#  '26699-2.0',
#  '26700-2.0',
#  '26701-2.0',
#  '26703-2.0',
#  '26704-2.0',
#  '26705-2.0',
#  '26706-2.0',
#  '26707-2.0',
#  '26708-2.0',
#  '26709-2.0',
#  '26710-2.0',
#  '26711-2.0',
#  '26712-2.0',
#  '26713-2.0',
#  '26714-2.0',
#  '26715-2.0',
#  '26716-2.0',
#  '26717-2.0',
#  '26718-2.0',
#  '26719-2.0',
#  '26720-2.0',
#  '26721-2.0',
#  '26722-2.0',
#  '26723-2.0',
#  '26724-2.0',
#  '26725-2.0',
#  '26726-2.0',
#  '26727-2.0',
#  '26728-2.0',
#  '26729-2.0',
#  '26730-2.0',
#  '26731-2.0',
#  '26732-2.0',
#  '26733-2.0',
#  '26734-2.0',
#  '26735-2.0',
#  '26736-2.0',
#  '26737-2.0',
#  '26738-2.0',
#  '26739-2.0',
#  '26740-2.0',
#  '26741-2.0',
#  '26742-2.0',
#  '26743-2.0',
#  '26744-2.0',
#  '26745-2.0',
#  '26746-2.0',
#  '26747-2.0',
#  '26748-2.0',
#  '26749-2.0',
#  '26750-2.0',
#  '26751-2.0',
#  '26752-2.0',
#  '26753-2.0',
#  '26754-2.0',
#  '26756-2.0',
#  '26757-2.0',
#  '26758-2.0',
#  '26759-2.0',
#  '26761-2.0',
#  '26762-2.0',
#  '26763-2.0',
#  '26764-2.0',
#  '26765-2.0',
#  '26767-2.0',
#  '26768-2.0',
#  '26769-2.0',
#  '26770-2.0',
#  '26771-2.0',
#  '26772-2.0',
#  '26773-2.0',
#  '26775-2.0',
#  '26776-2.0',
#  '26777-2.0',
#  '26778-2.0',
#  '26779-2.0',
#  '26780-2.0',
#  '26782-2.0',
#  '26783-2.0',
#  '26784-2.0',
#  '26785-2.0',
#  '26786-2.0',
#  '26787-2.0',
#  '26788-2.0',
#  '26789-2.0',
#  '26790-2.0',
#  '26791-2.0',
#  '26792-2.0',
#  '26793-2.0',
#  '26794-2.0',
#  '26795-2.0',
#  '26796-2.0',
#  '26797-2.0',
#  '26798-2.0',
#  '26799-2.0',
#  '26800-2.0',
#  '26801-2.0',
#  '26802-2.0',
#  '26803-2.0',
#  '26804-2.0',
#  '26805-2.0',
#  '26806-2.0',
#  '26807-2.0',
#  '26808-2.0',
#  '26809-2.0',
#  '26810-2.0',
#  '26811-2.0',
#  '26812-2.0',
#  '26813-2.0',
#  '26814-2.0',
#  '26815-2.0',
#  '26816-2.0',
#  '26817-2.0',
#  '26818-2.0',
#  '26819-2.0',
#  '26820-2.0',
#  '26821-2.0',
#  '26822-2.0',
#  '26823-2.0',
#  '26824-2.0',
#  '26825-2.0',
#  '26826-2.0',
#  '26827-2.0',
#  '26828-2.0',
#  '26829-2.0',
#  '26830-2.0',
#  '26831-2.0',
#  '26832-2.0',
#  '26833-2.0',
#  '26834-2.0',
#  '26835-2.0',
#  '26836-2.0',
#  '26837-2.0',
#  '26838-2.0',
#  '26839-2.0',
#  '26840-2.0',
#  '26841-2.0',
#  '26842-2.0',
#  '26843-2.0',
#  '26844-2.0',
#  '26845-2.0',
#  '26846-2.0',
#  '26847-2.0',
#  '26848-2.0',
#  '26849-2.0',
#  '26850-2.0',
#  '26851-2.0',
#  '26852-2.0',
#  '26853-2.0',
#  '26854-2.0',
#  '26855-2.0',
#  '26856-2.0',
#  '26857-2.0',
#  '26858-2.0',
#  '26859-2.0',
#  '26860-2.0',
#  '26861-2.0',
#  '26862-2.0',
#  '26863-2.0',
#  '26864-2.0',
#  '26865-2.0',
#  '26866-2.0',
#  '26867-2.0',
#  '26868-2.0',
#  '26870-2.0',
#  '26871-2.0',
#  '26872-2.0',
#  '26873-2.0',
#  '26874-2.0',
#  '26876-2.0',
#  '26877-2.0',
#  '26878-2.0',
#  '26879-2.0',
#  '26880-2.0',
#  '26881-2.0',
#  '26883-2.0',
#  '26884-2.0',
#  '26885-2.0',
#  '26886-2.0',
#  '26887-2.0',
#  '26890-2.0',
#  '26891-2.0',
#  '26892-2.0',
#  '26893-2.0',
#  '26894-2.0',
#  '26895-2.0',
#  '26896-2.0',
#  '26897-2.0',
#  '26898-2.0',
#  '26899-2.0',
#  '26900-2.0',
#  '26901-2.0',
#  '26902-2.0',
#  '26903-2.0',
#  '26904-2.0',
#  '26905-2.0',
#  '26906-2.0',
#  '26907-2.0',
#  '26908-2.0',
#  '26909-2.0',
#  '26910-2.0',
#  '26911-2.0',
#  '26912-2.0',
#  '26913-2.0',
#  '26914-2.0',
#  '26915-2.0',
#  '26916-2.0',
#  '26917-2.0',
#  '26918-2.0',
#  '26919-2.0',
#  '26920-2.0',
#  '26921-2.0',
#  '26922-2.0',
#  '26923-2.0',
#  '26924-2.0',
#  '26925-2.0',
#  '26926-2.0',
#  '26927-2.0',
#  '26928-2.0',
#  '26929-2.0',
#  '26930-2.0',
#  '26931-2.0',
#  '26932-2.0',
#  '26933-2.0',
#  '26934-2.0',
#  '26935-2.0',
#  '26936-2.0',
#  '26937-2.0',
#  '26938-2.0',
#  '26939-2.0',
#  '26940-2.0',
#  '26941-2.0',
#  '26942-2.0',
#  '26943-2.0',
#  '26944-2.0',
#  '26945-2.0',
#  '26946-2.0',
#  '26947-2.0',
#  '26948-2.0',
#  '26949-2.0',
#  '26950-2.0',
#  '26951-2.0',
#  '26952-2.0',
#  '26953-2.0',
#  '26954-2.0',
#  '26955-2.0',
#  '26956-2.0',
#  '26957-2.0',
#  '26958-2.0',
#  '26959-2.0',
#  '26960-2.0',
#  '26961-2.0',
#  '26962-2.0',
#  '26963-2.0',
#  '26964-2.0',
#  '26965-2.0',
#  '26966-2.0',
#  '26967-2.0',
#  '26968-2.0',
#  '26969-2.0',
#  '26970-2.0',
#  '26971-2.0',
#  '26972-2.0',
#  '26973-2.0',
#  '26974-2.0',
#  '26975-2.0',
#  '26976-2.0',
#  '26977-2.0',
#  '26978-2.0',
#  '26979-2.0',
#  '26980-2.0',
#  '26981-2.0',
#  '26982-2.0',
#  '26983-2.0',
#  '26984-2.0',
#  '26985-2.0',
#  '26986-2.0',
#  '26987-2.0',
#  '26988-2.0',
#  '26989-2.0',
#  '26990-2.0',
#  '26991-2.0',
#  '26992-2.0',
#  '26993-2.0',
#  '26995-2.0',
#  '26996-2.0',
#  '26997-2.0',
#  '26998-2.0',
#  '26999-2.0',
#  '27000-2.0',
#  '27001-2.0',
#  '27002-2.0',
#  '27003-2.0',
#  '27004-2.0',
#  '27005-2.0',
#  '27006-2.0',
#  '27007-2.0',
#  '27008-2.0',
#  '27009-2.0',
#  '27010-2.0',
#  '27011-2.0',
#  '27012-2.0',
#  '27013-2.0',
#  '27015-2.0',
#  '27016-2.0',
#  '27017-2.0',
#  '27018-2.0',
#  '27019-2.0',
#  '27020-2.0',
#  '27021-2.0',
#  '27022-2.0',
#  '27023-2.0',
#  '27024-2.0',
#  '27025-2.0',
#  '27026-2.0',
#  '27027-2.0',
#  '27028-2.0',
#  '27029-2.0',
#  '27030-2.0',
#  '27031-2.0',
#  '27032-2.0',
#  '27033-2.0',
#  '27034-2.0',
#  '27035-2.0',
#  '27036-2.0',
#  '27037-2.0',
#  '27038-2.0',
#  '27039-2.0',
#  '27040-2.0',
#  '27041-2.0',
#  '27042-2.0',
#  '27043-2.0',
#  '27044-2.0',
#  '27045-2.0',
#  '27046-2.0',
#  '27047-2.0',
#  '27048-2.0',
#  '27049-2.0',
#  '27050-2.0',
#  '27051-2.0',
#  ...]

# %%
# testing the idea of education as protective for cognitive function, using imaging data as covariates
from econml.dml import CausalForestDML
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from doubleml_utils import run_dml

df = covariates_df.fillna(covariates_df.mean())

# treatment as education, outcome as cognitive test scores, x as imaging data
results = {}
cates = {}

for test in overlap_cog:
    nan_count = df[test].isna().sum()
    nan_pct = nan_count / len(df)
    if nan_count > 0 and nan_pct < 0.2:
        df = df[df[test].notna()]

    Y = df[test].values
    T = df['education_years'].values
    X = df.drop(columns=overlap_cog + ['education_years', 'groups', 'eid']).values

    # DML with forest-based CATE estimator
    model = CausalForestDML(
        model_y=GradientBoostingRegressor(),
        model_t=GradientBoostingRegressor(),
        n_estimators=100,
        min_samples_leaf=10,
        max_depth=10,
        discrete_treatment=False,
        random_state=42
    )
    model.fit(Y, T, X=X)

    # Estimate overall ATE
    ate = model.ate(X)
    results[test] = {"ATE": ate, "model": model, "summary": model.summary}

    # Estimate CATEs
    cate = model.effect(X)
    cates[test] = cate
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 32
#      22 # DML with forest-based CATE estimator
#      23 model = CausalForestDML(
#      24     model_y=GradientBoostingRegressor(),
#      25     model_t=GradientBoostingRegressor(),
#    (...)
#      30     random_state=42
#      31 )
# ---> 32 model.fit(Y, T, X=X)
#      34 # Estimate overall ATE
#      35 ate = model.ate(X)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/dml/causal_forest.py:964, in CausalForestDML.fit(self, Y, T, X, W, sample_weight, groups, cache_values, inference)
#     962 if X is None:
#     963     raise ValueError("This estimator does not support X=None!")
# --> 964 return super().fit(Y, T, X=X, W=W,
#     965                    sample_weight=sample_weight, groups=groups,
#     966                    cache_values=cache_values,
#     967                    inference=inference)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/dml/_rlearner.py:501, in _RLearner.fit(self, Y, T, X, W, sample_weight, freq_weight, sample_var, groups, cache_values, inference)
#     464 """
#     465 Estimate the counterfactual model from data, i.e. estimates function :math:`\\theta(\\cdot)`.
#     466
#    (...)
#     498 self: _RLearner instance
#     499 """
#     500 # Replacing fit from _OrthoLearner, to enforce Z=None and improve the docstring
# --> 501 return super().fit(Y, T, X=X, W=W,
#     502                    sample_weight=sample_weight, freq_weight=freq_weight, sample_var=sample_var, groups=groups,
#     503                    cache_values=cache_values,
#     504                    inference=inference)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/_cate_estimator.py:134, in BaseCateEstimator._wrap_fit.<locals>.call(self, Y, T, inference, *args, **kwargs)
#     132     inference.prefit(self, Y, T, *args, **kwargs)
#     133 # call the wrapped fit method
# --> 134 m(self, Y, T, *args, **kwargs)
#     135 self._postfit(Y, T, *args, **kwargs)
#     136 if inference is not None:
#     137     # NOTE: we call inference fit *after* calling the main fit method
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/_ortho_learner.py:821, in _OrthoLearner.fit(self, Y, T, X, W, Z, sample_weight, freq_weight, sample_var, groups, cache_values, inference, only_final, check_input)
#     819     nuisances, fitted_models, new_inds, scores = ray.get(self.nuisances_ref[idx])
#     820 else:
# --> 821     nuisances, fitted_models, new_inds, scores = self._fit_nuisances(
#     822         Y, T, X, W, Z, sample_weight=sample_weight_nuisances, groups=groups)
#     823 all_nuisances.append(nuisances)
#     824 self._models_nuisance.append(fitted_models)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/_ortho_learner.py:971, in _OrthoLearner._fit_nuisances(self, Y, T, X, W, Z, sample_weight, groups)
#     968     else:
#     969         folds = splitter.split(to_split, strata)
# --> 971 nuisances, fitted_models, fitted_inds, scores = _crossfit(self._ortho_learner_model_nuisance, folds,
#     972                                                           self.use_ray, self.ray_remote_func_options, Y, T,
#     973                                                           X=X, W=W, Z=Z, sample_weight=sample_weight,
#     974                                                           groups=groups)
#     975 return nuisances, fitted_models, fitted_inds, scores
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/_ortho_learner.py:278, in _crossfit(models, folds, use_ray, ray_remote_fun_option, *args, **kwargs)
#     276     nuisance_temp, model_out, score_temp = ray.get(fold_refs[idx])
#     277 else:
# --> 278     nuisance_temp, model_out, score_temp = _fit_fold(model, train_idxs, test_idxs,
#     279                                                      calculate_scores, accumulated_args, kwargs)
#     281 if idx == 0:
#     282     nuisances = tuple([np.full((n,) + nuis.shape[1:], np.nan)
#     283                       for nuis in nuisance_temp])
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/_ortho_learner.py:97, in _fit_fold(model, train_idxs, test_idxs, calculate_scores, args, kwargs)
#      94 kwargs_train = {key: var[train_idxs] for key, var in kwargs.items()}
#      95 kwargs_test = {key: var[test_idxs] for key, var in kwargs.items()}
# ---> 97 model.train(False, None, *args_train, **kwargs_train)
#      98 nuisance_temp = model.predict(*args_test, **kwargs_test)
#     100 if not isinstance(nuisance_temp, tuple):
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/dml/_rlearner.py:55, in _ModelNuisance.train(self, is_selecting, folds, Y, T, X, W, Z, sample_weight, groups)
#      53 def train(self, is_selecting, folds, Y, T, X=None, W=None, Z=None, sample_weight=None, groups=None):
#      54     assert Z is None, "Cannot accept instrument!"
# ---> 55     self._model_t.train(is_selecting, folds, X, W, T, **
#      56                         filter_none_kwargs(sample_weight=sample_weight, groups=groups))
#      57     self._model_y.train(is_selecting, folds, X, W, Y, **
#      58                         filter_none_kwargs(sample_weight=sample_weight, groups=groups))
#      59     return self
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/dml/dml.py:110, in _FirstStageSelector.train(self, is_selecting, folds, X, W, Target, sample_weight, groups)
#     106         raise AttributeError("Provided crossfit folds contain training splits that " +
#     107                              "don't contain all treatments")
#     108     Target = inverse_onehot(Target)
# --> 110 self._model.train(is_selecting, folds, _combine(X, W, Target.shape[0]), Target,
#     111                   **filter_none_kwargs(groups=groups, sample_weight=sample_weight))
#     112 return self
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/sklearn_extensions/model_selection.py:405, in FixedModelSelector.train(self, is_selecting, folds, X, y, groups, **kwargs)
#     402         self._score = np.mean(scores)
#     403 else:
#     404     # we need to train the model on the data
# --> 405     _fit_with_groups(self.model, X, y, groups=groups, **kwargs)
#     407 return self
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/econml/sklearn_extensions/model_selection.py:378, in _fit_with_groups(model, X, y, sub_model, groups, **kwargs)
#     375             sub_model.cv = old_cv
#     377 # drop groups from arg list, which were already used at the outer level and may not be supported by the model
# --> 378 return model.fit(X, y, **kwargs)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:787, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     784     self._resize_state()
#     786 # fit the boosting stages
# --> 787 n_stages = self._fit_stages(
#     788     X_train,
#     789     y_train,
#     790     raw_predictions,
#     791     sample_weight_train,
#     792     self._rng,
#     793     X_val,
#     794     y_val,
#     795     sample_weight_val,
#     796     begin_at_stage,
#     797     monitor,
#     798 )
#     800 # change shape of arrays after fit (early-stopping or additional ests)
#     801 if n_stages != self.estimators_.shape[0]:
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:883, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     876         initial_loss = factor * self._loss(
#     877             y_true=y_oob_masked,
#     878             raw_prediction=raw_predictions[~sample_mask],
#     879             sample_weight=sample_weight_oob_masked,
#     880         )
#     882 # fit next stage of trees
# --> 883 raw_predictions = self._fit_stage(
#     884     i,
#     885     X,
#     886     y,
#     887     raw_predictions,
#     888     sample_weight,
#     889     sample_mask,
#     890     random_state,
#     891     X_csc=X_csc,
#     892     X_csr=X_csr,
#     893 )
#     895 # track loss
#     896 if do_oob:
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:489, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     486     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     488 X = X_csc if X_csc is not None else X
# --> 489 tree.fit(
#     490     X, neg_g_view[:, k], sample_weight=sample_weight, check_input=False
#     491 )
#     493 # update tree leaves
#     494 X_for_tree_update = X_csr if X_csr is not None else X
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/tree/_classes.py:1404, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1374 @_fit_context(prefer_skip_nested_validation=True)
#    1375 def fit(self, X, y, sample_weight=None, check_input=True):
#    1376     """Build a decision tree regressor from the training set (X, y).
#    1377
#    1378     Parameters
#    (...)
#    1401         Fitted estimator.
#    1402     """
# -> 1404     super()._fit(
#    1405         X,
#    1406         y,
#    1407         sample_weight=sample_weight,
#    1408         check_input=check_input,
#    1409     )
#    1410     return self
#
# File ~/.conda/envs/lowpyAD/lib/python3.10/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
cates.to_csv('CATES_FOR_LATER.csv')

# %%
import pandas as pd

cate_df = pd.DataFrame(cates[test], columns=['cate'])
brain_df = df.drop(columns=overlap_cog + ['education_years', 'groups', 'eid']).reset_index(drop=True)

corr = cate_df['cate'].corr(brain_df['hippocampal_volume'])  # example

# %%
results

# %% [markdown]
# Path Analysis

# %%
from sklearn.decomposition import PCA

imaging_df_scaled.fillna(imaging_df_scaled.mean(), inplace=True)
image_only = imaging_df_scaled.drop(columns=['eid'])


# Reduce 500 brain variables to 20 components
brain_pca = PCA(n_components=20).fit_transform(image_only[overlap_image])
for i in range(20):
    imaging_df_scaled[f'brain_pc{i+1}'] = brain_pca[:, i]

# %%
imaging_df_scaled = imaging_df_scaled.merge(covariates_df, on='eid', how='inner')

# %%
final_df = imaging_df_scaled[['eid', 'education_years', 'groups']+overlap_image + overlap_cog]

# %%
final_df.to_parquet('imaging_ed_cog_brain_FOR_R.parquet', engine = 'fastparquet', index=False)

# %%
hmmm_df = imaging_df_scaled.merge(covariates_df, on='eid', how='inner')
final_df = hmmm_df[['eid', 'education_years', 'groups']+[col for col in hmmm_df.columns if (col.startswith('25') or col.startswith('27') or col.startswith('26'))] + overlap_cog]
final_df

# %%
final_df['eid'] = final_df['eid'].astype('int64')

final_df.to_parquet('imaging_ed_cog_brain_FOR_R.parquet', engine = 'fastparquet')

# %%
final_df.isna().sum()

# %%
brain_pca = PCA(n_components=20)
brain_pca.fit(imaging_df_scaled[overlap_image])
loadings = pd.DataFrame(brain_pca.components_, columns=imaging_df_scaled[overlap_image].columns)
loadings.abs().idxmax(axis=1)

# %%
final_df.isna().sum()

# %%
from semopy import Model, Optimizer
import pandas as pd

final_df.fillna(final_df.mean(), inplace=True)

# Debug: Check what we're working with
print("overlap_cog:", overlap_cog)
print("Available columns:", final_df.columns.tolist())

# Rename columns in final_df to match what we expect
cog_vars_clean = []
for var in overlap_cog:
    clean_var = var.replace('-', '_').replace('.', '_')
    # Rename the column in the dataframe if original exists
    if var in final_df.columns:
        final_df = final_df.rename(columns={var: clean_var})
        cog_vars_clean.append(clean_var)
        print(f"Renamed {var} -> {clean_var}")
    elif clean_var in final_df.columns:
        # Already renamed
        cog_vars_clean.append(clean_var)
        print(f"Found already cleaned variable: {clean_var}")
    else:
        print(f"WARNING: {var} not found in final_df")

if len(cog_vars_clean) == 0:
    print("ERROR: No cognitive variables found!")
else:
    cog_vars = " + ".join(cog_vars_clean)
    print("Final cog_vars string:", repr(cog_vars))

    desc = f"""
brain_reserve =~ brain_pc1 + brain_pc2 + brain_pc3 + brain_pc4 + brain_pc5 + brain_pc6 + brain_pc7 + brain_pc8 + brain_pc9 + brain_pc10 + brain_pc11 + brain_pc12 + brain_pc13 + brain_pc14 + brain_pc15 + brain_pc16 + brain_pc17 + brain_pc18 + brain_pc19 + brain_pc20
cognitive_reserve =~ {cog_vars}

brain_reserve ~ education_years
cognitive_reserve ~ education_years + brain_reserve
groups ~ education_years + brain_reserve + cognitive_reserve
"""

    print("Model specification:")
    print(desc)

    try:
        model = Model(desc)
        model.fit(final_df)
        report = model.inspect(std_est=True)
        print(report)
    except Exception as e:
        print(f"Model error: {e}")

# %%
report.head(20)

# %%
report

# %% [markdown]
# Mediation - Education, Images, AD

# %%
import networkx as nx
from dowhy import CausalModel
from dowhy.causal_estimators import linear_regression_estimator
from dowhy.causal_estimators.regression_estimator import RegressionEstimator
import pandas as pd

mediators = overlap  # List of mediators from the mediation analysis
results = []

covariates_df = covariates_df.dropna(subset=['education_years', 'curr_age', '31-0.0'])

for mediator in mediators:
        # Create a subgraph with only the current mediator
        gml_graph_single = f"""
        graph [
        directed 1
        node [ id 0 label "education_years" ]
        node [ id 1 label "groups" ]
        node [ id 2 label "{mediator}" ]
        node [ id 3 label "e2/e2" ]
        node [ id 4 label "e3/e3" ]
        node [ id 5 label "e2/e3" ]
        node [ id 6 label "e3/e4" ]
        node [ id 7 label "e2/e4" ]
        node [ id 8 label "e4/e4" ]
        node [ id 9 label "curr_age" ]
        node [ id 10 label "31-0.0" ]
        # Covariates to treatment and outcome
        edge [ source 3 target 0 ]
        edge [ source 3 target 1 ]
        edge [ source 4 target 0 ]
        edge [ source 4 target 1 ]
        edge [ source 5 target 0 ]
        edge [ source 5 target 1 ]
        edge [ source 6 target 0 ]
        edge [ source 6 target 1 ]
        edge [ source 7 target 0 ]
        edge [ source 7 target 1 ]
        edge [ source 8 target 0 ]
        edge [ source 8 target 1 ]
        edge [ source 9 target 0 ]
        edge [ source 9 target 1 ]
        edge [ source 10 target 0 ]
        edge [ source 10 target 1 ]

        # Covariates to mediator
        edge [ source 3 target 2 ]
        edge [ source 4 target 2 ]
        edge [ source 5 target 2 ]
        edge [ source 6 target 2 ]
        edge [ source 7 target 2 ]
        edge [ source 8 target 2 ]
        edge [ source 9 target 2 ]
        edge [ source 10 target 2 ]

        # Treatment to mediator
        edge [ source 0 target 2 ]
        # Mediator to outcome
        edge [ source 2 target 1 ]
        ]

        edge [ source 0 target 1 ]
        """
        with open("causal_graph_single.gml", "w") as f:
            f.write(gml_graph_single)
        gml_graph = nx.read_gml("causal_graph_single.gml")

        covariates_df = covariates_df.dropna(subset=mediator)
    
        model = CausalModel(
            data=covariates_df,
            treatment='education_years',
            outcome='groups',
            graph=gml_graph,
        )

        identified_estimand_indirect = model.identify_effect(estimand_type='nonparametric-nie', proceed_when_unidentifiable=True)
        #print(identified_estimand_indirect)

        causal_estimate_nie = model.estimate_effect(
            identified_estimand_indirect,
            method_name="mediation.two_stage_regression",
            control_value = 0,
            treatment_value = 1,
            effect_modifiers = ['e2/e2', 'e3/e3', 'e2/e3', 'e3/e4', 'e2/e4', 'e4/e4'],
            confidence_intervals=False,
            test_significance=False,
            method_params={
                'first_stage_model': linear_regression_estimator.LinearRegressionEstimator,
                'second_stage_model': linear_regression_estimator.LinearRegressionEstimator,
            }
        )
        results.append({
            'mediator': mediator,
            'nie': causal_estimate_nie.value,
            #'CATE': causal_estimate_nie.cate_estimates, 
        })

# %%
from semopy import Model, Optimizer
import pandas as pd

desc = """
brain_reserve =~ hippocampal_volume + icv + cortical_thickness
cognitive_reserve =~ memory_score + executive_function + processing_speed

brain_reserve ~ education_years
cognitive_reserve ~ education_years + brain_reserve
ad_dx ~ education_years + brain_reserve + cognitive_reserve
"""

model = Model(desc)
model.fit(df)  # df = pandas DataFrame
report = model.inspect(std_est=True)

# %%
results = pd.DataFrame(results).sort_values(by='nie', key=abs, ascending=False)

# %%
results.to_csv('./double_ml/imaging_ed_to_AD_mediation_results.csv', index=False)
